tsv
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/native_script_wikipedia/sd.wiki-full.nonblock.sections.list.txt/wiki-full.nonblock.sections.list.txt
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/native_script_wikipedia/sd.wiki-full.info.sorted.tsv/wiki-full.info.sorted.tsv
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.rejoined.test.native.txt
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.split.validation.edits.txt
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.rejoined.tsv
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.rejoined.dev.roman.txt
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.split.tsv
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.rejoined.aligned.cased_nopunct.tsv
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.rejoined.dev.native.txt
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.rejoined.test.roman.txt
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.split.validation.native.txt
# /kaggle/input/3dataset/dakshina_dataset_v1.0/sd/romanized/sd.romanized.rejoined.aligned.tsv
# /kaggle/input/snehal/hi.translit.sampled.dev.tsv
# /kaggle/input/snehal/hi.translit.sampled.test.tsv
# /kaggle/input/snehal/hi.translit.sampled.train.tsv

# %% [markdown]
# # Step 1 : Setting up the wandb

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("wandb")

# %%
import wandb
wandb.login(key=secret_value_0)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ma23m020 (snehalma23m020-iit-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Step 2 : importing the important libraries and loading the path of datafiles

# %%
import torch
import torch.nn as nn
import os
import random
import pandas as pd
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import wandb
from IPython.display import HTML, display

train_path = "/kaggle/input/snehal/hi.translit.sampled.train.tsv"
dev_path   = "/kaggle/input/snehal/hi.translit.sampled.dev.tsv"
test_path  = "/kaggle/input/snehal/hi.translit.sampled.test.tsv"

# %% [markdown]
# # Step 3 : Implementing a flexible RNN-based character-level Seq2Seq model with configurable RNN cell type (RNN/LSTM/GRU), number of layers, and embedding/hidden dimensions. It uses an encoder-decoder architecture to translate sequences from a source vocabulary (e.g., Latin) to a target vocabulary (e.g., Devanagari).

# %%
class CharSeq2Seq(nn.Module):
    def __init__(self, input_vocab_size,target_vocab_size,embedding_dim,hidden_size,num_layers,cell_type='LSTM'):
        super(CharSeq2Seq, self).__init__()

           # RNN types
        assert cell_type in ['RNN', 'LSTM', 'GRU'], "Unsupported RNN cell type"

        self.cell_type = cell_type
        self.embedding_dim = embedding_dim
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        # Input Embedding layers
        self.encoder_embedding = nn.Embedding(input_vocab_size, embedding_dim) # for encoder
        self.decoder_embedding = nn.Embedding(target_vocab_size, embedding_dim) # for decoder

        # RNN cell type constructor (RNN / LSTM / GRU)
        rnn_cell = getattr(nn, cell_type)

        # Encoder rnn
        self.encoder_rnn = rnn_cell(embedding_dim, hidden_size, num_layers, batch_first=True)
        
        # Decoder rnn
        self.decoder_rnn = rnn_cell(embedding_dim, hidden_size, num_layers, batch_first=True)

        #  Output projection from decoder hidden state to target vocab size
        self.fc_out = nn.Linear(hidden_size, target_vocab_size)

    def forward(self, src, tgt):
        """
        src: [batch_size, src_seq_len] - input/source sequence
        tgt: [batch_size, tgt_seq_len] - output/target sequence
        """
        batch_size = src.size(0)

        #fFor Encoder
        embedded_src = self.encoder_embedding(src)  # [batch_size, src_len, embed_dim]
        encoder_outputs, hidden = self.encoder_rnn(embedded_src)  # hidden: [num_layers, batch, hidden_size]

        # For Decoder
        embedded_tgt = self.decoder_embedding(tgt)  # [batch_size, tgt_len, embed_dim]
        decoder_outputs, _ = self.decoder_rnn(embedded_tgt, hidden)  # [batch, tgt_len, hidden_size]

        # Project decoder outputs to target vocab space
        logits = self.fc_out(decoder_outputs)  # [batch, tgt_len, target_vocab_size]

        return logits

# %% [markdown]
# # Step 4 : set the seed for reproducibility and setting up the device

# %%
def set_seed(seed=42):
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Step 5 : Loading the dataset ( Dakshina dataset)

# %%
def load_dakshina_pairs(path):
    """
    Returns list of (latin, devanagari) pairs with all NaNs removed.
    """
    df = (
        pd.read_csv(path,sep="\t",names=["native", "latin", "count"],
            dtype={"native": str, "latin": str, "count": str}  # force strings
        )
        .dropna(subset=["native", "latin"])       # <-- NEW: keep only complete rows
    )

    # strip any stray whitespace
    df["native"] = df["native"].str.strip()
    df["latin"]  = df["latin"].str.strip()

    # remove empty strings (after strip)
    df = df[(df["native"] != "") & (df["latin"] != "")]
    return list(zip(df["latin"], df["native"]))

# %% [markdown]
# # Step 6 : The build_vocab function constructs character-level vocabularies for source and target scripts, including special tokens. The TransliterationDataset prepares source-target sequence pairs with proper tokenization and padding for training a character-level Seq2Seq transliteration model.

# %%
# Function to build character vocabularies for input (Latin) and target (Devanagari)
def build_vocab(pairs, special_tokens=["<pad>", "<sos>", "<eos>", "<unk>"]):
    # Extract unique characters from source (Latin) and target (Devanagari) strings
    input_chars = sorted(set("".join(src for src, _ in pairs)))
    target_chars = sorted(set("".join(trg for _, trg in pairs)))
    ## Prepend special tokens to character vocabularies
    input_vocab = special_tokens + input_chars
    target_vocab = special_tokens + target_chars
    return input_vocab, target_vocab

# Dataset for training
# Dataset class for preparing tokenized and padded (src, tgt) character sequences
class TransliterationDataset(Dataset):
    def __init__(self, pairs, input_char2idx, target_char2idx, max_input_len, max_output_len):
        self.pairs = pairs
        self.input_char2idx = input_char2idx # mapping for input (Latin) characters
        self.target_char2idx = target_char2idx # mapping for outut (devnagri) characters
        self.max_input_len = max_input_len   # max allowed input length
        self.max_output_len = max_output_len # max allowed output length

    def __len__(self):
        return len(self.pairs)
    def __getitem__(self, idx):
        latin, devanagari = self.pairs[idx]

        # Convert Latin characters to indices with <sos> and <eos>
        src_seq = [self.input_char2idx["<sos>"]] + [self.input_char2idx.get(ch, self.input_char2idx["<unk>"]) for ch in latin] + [self.input_char2idx["<eos>"]]

        # Convert Devanagari characters to indices with <sos> and <eos>
        tgt_seq = [self.target_char2idx["<sos>"]] + [self.target_char2idx.get(ch, self.target_char2idx["<unk>"]) for ch in devanagari] + [self.target_char2idx["<eos>"]]
       
        # Pad sequences to max lengths
        src_seq += [self.input_char2idx["<pad>"]] * (self.max_input_len - len(src_seq))
        tgt_seq += [self.target_char2idx["<pad>"]] * (self.max_output_len - len(tgt_seq))
        return torch.tensor(src_seq), torch.tensor(tgt_seq)

# %% [markdown]
# # step 7 : Basic Seq2Seq Model
# A flexible Seq2Seq model for character-level transliteration, supporting RNN/LSTM/GRU cells, optional bidirectional encoding, and configurable layers. It embeds input/output tokens, encodes the source, and then decodes using the last hidden state to predict target sequences.

# %%
# Basic Seq2Seq Model for Transliteration
class Seq2Seq(nn.Module):
    def __init__(self, input_vocab_size, target_vocab_size, embedding_dim, hidden_size,encoder_layers, decoder_layers, rnn_type="LSTM", dropout=0.2, bidirectional=False):
        super(Seq2Seq, self).__init__()
        assert rnn_type in ["RNN", "LSTM", "GRU"]
        self.rnn_type = rnn_type
        self.bidirectional = bidirectional
        self.encoder_directions = 2 if bidirectional else 1

        # Embedding layers for source and target
        self.encoder_embedding = nn.Embedding(input_vocab_size, embedding_dim)
        self.decoder_embedding = nn.Embedding(target_vocab_size, embedding_dim)

        rnn_cls = getattr(nn, rnn_type)

          # Encoder RNN (can be multi-layered and bidirectional)
        self.encoder_rnn = rnn_cls(embedding_dim, hidden_size, encoder_layers,batch_first=True,dropout=dropout if encoder_layers > 1 else 0, bidirectional=bidirectional)

        # Decoder RNN 
        self.decoder_rnn = rnn_cls(embedding_dim, hidden_size, decoder_layers,batch_first=True,dropout=dropout if decoder_layers > 1 else 0)

        self.dropout = nn.Dropout(dropout)  # Dropout regularization

        # Final linear layer to project decoder output to vocabulary space
        self.fc_out = nn.Linear(hidden_size, target_vocab_size)

        if bidirectional:
            self.bridge = nn.Linear(hidden_size * 2, hidden_size)

        self.encoder_layers = encoder_layers
        self.decoder_layers = decoder_layers
        self.hidden_size = hidden_size

    def forward(self, src, tgt):

         # Embed sequences
        src_embed = self.dropout(self.encoder_embedding(src))
        tgt_embed = self.dropout(self.decoder_embedding(tgt))

        # Encode input using encoder RNN
        encoder_outputs, encoder_hidden = self.encoder_rnn(src_embed)

        # Prepare initial hidden state for decoder
        def _bridge(hidden):
            if self.rnn_type == "LSTM":
                h, c = hidden
                h_fwd = h[-2, :, :]
                h_bwd = h[-1, :, :]
                h_cat = torch.cat([h_fwd, h_bwd], dim=1)
                h_proj = self.bridge(h_cat).unsqueeze(0).repeat(self.decoder_layers, 1, 1)

                c_fwd = c[-2, :, :]
                c_bwd = c[-1, :, :]
                c_cat = torch.cat([c_fwd, c_bwd], dim=1)
                c_proj = self.bridge(c_cat).unsqueeze(0).repeat(self.decoder_layers, 1, 1)
                return (h_proj, c_proj)
            else:
                h_fwd = hidden[-2, :, :]
                h_bwd = hidden[-1, :, :]
                h_cat = torch.cat([h_fwd, h_bwd], dim=1)
                h_proj = self.bridge(h_cat).unsqueeze(0).repeat(self.decoder_layers, 1, 1)
                return h_proj

        if self.bidirectional:
            decoder_hidden = _bridge(encoder_hidden)
        else:
            if self.rnn_type == "LSTM":
                h, c = encoder_hidden
                if h.shape[0] != self.decoder_layers:
                    h = h[-1:, :, :].repeat(self.decoder_layers, 1, 1)
                    c = c[-1:, :, :].repeat(self.decoder_layers, 1, 1)
                decoder_hidden = (h, c)
            else:
                h = encoder_hidden
                if h.shape[0] != self.decoder_layers:
                    h = h[-1:, :, :].repeat(self.decoder_layers, 1, 1)
                decoder_hidden = h

         # Decode target sequence
        decoder_outputs, _ = self.decoder_rnn(tgt_embed, decoder_hidden)

          # Project decoder outputs to target vocabulary logits
        return self.fc_out(decoder_outputs)

# %% [markdown]
# # Step 8 : Training function for WandB

# %%
def train(config=None):
    with wandb.init(config=config):
        config = wandb.config  # load hyperparameters from sweep config


        # Load training and validation data
        train_pairs = load_dakshina_pairs(train_path)
        dev_pairs = load_dakshina_pairs(dev_path)

         # Build vocabularies and mappings
        input_vocab, target_vocab = build_vocab(train_pairs)
        input_char2idx = {c: i for i, c in enumerate(input_vocab)}
        target_char2idx = {c: i for i, c in enumerate(target_vocab)}

        
        # Compute max sequence lengths (+2 for <sos>, <eos>)
        max_input_len = max(len(x[0]) for x in train_pairs) + 2
        max_output_len = max(len(x[1]) for x in train_pairs) + 2

         # DataLoaders
        train_ds = TransliterationDataset(train_pairs, input_char2idx, target_char2idx, max_input_len, max_output_len)
        dev_ds = TransliterationDataset(dev_pairs, input_char2idx, target_char2idx, max_input_len, max_output_len)
        train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
        dev_loader = DataLoader(dev_ds, batch_size=64)

        PAD_IDX  = target_char2idx["<pad>"]
        EOS_IDX  = target_char2idx["<eos>"]
        target_idx2char = {i: c for c, i in target_char2idx.items()}

        #  Evaluation function to compute accuracy
        def evaluate():
            model.eval()
            corr_chars, tot_chars = 0, 0
            corr_words, tot_words = 0, 0

            with torch.no_grad():
                for src, tgt in dev_loader:
                    src, tgt = src.to(device), tgt.to(device)
                    logits = model(src, tgt[:, :-1])
                    pred   = torch.argmax(logits, dim=-1)

                    # Character-level accuracy
                    mask = tgt[:, 1:] != PAD_IDX
                    corr_chars += (pred == tgt[:,1:]).masked_select(mask).sum().item()
                    tot_chars   += mask.sum().item()

                    # word‐level exact match
                    B, T = pred.size()
                    for i in range(B):
                        gold_idxs = tgt[i,1:].tolist()
                        pred_idxs = pred[i].tolist()

                        if EOS_IDX in gold_idxs:
                            gold_idxs = gold_idxs[:gold_idxs.index(EOS_IDX)]
                        if EOS_IDX in pred_idxs:
                            pred_idxs = pred_idxs[:pred_idxs.index(EOS_IDX)]

                        gold_str = "".join(target_idx2char[idx] for idx in gold_idxs)
                        pred_str = "".join(target_idx2char[idx] for idx in pred_idxs)

                        if pred_str == gold_str:
                            corr_words += 1
                        tot_words += 1

            char_acc = corr_chars / tot_chars
            word_acc = corr_words / tot_words
            return char_acc, word_acc

        
        # Instantiate model with sweep-configured hyperparameters
        model = Seq2Seq(
            input_vocab_size=len(input_vocab),
            target_vocab_size=len(target_vocab),
            embedding_dim=config.embedding_dim,
            hidden_size=config.hidden_size,
            encoder_layers=config.encoder_layers,
            decoder_layers=config.decoder_layers,
            rnn_type=config.cell_type,
            dropout=config.dropout,
            bidirectional=config.bidirectional 
        ).to(device)

        criterion = nn.CrossEntropyLoss(ignore_index=target_char2idx["<pad>"])
        optimizer = optim.Adam(model.parameters(), lr=0.001)

        # def evaluate():
        #     model.eval()
        #     correct, total = 0, 0
        #     with torch.no_grad():
        #         for src, tgt in dev_loader:
        #             src, tgt = src.to(device), tgt.to(device)
        #             output = model(src, tgt[:, :-1])
        #             pred = torch.argmax(output, dim=-1)
        #             mask = tgt[:, 1:] != target_char2idx["<pad>"]
        #             correct += (pred == tgt[:, 1:]).masked_select(mask).sum().item()
        #             total += mask.sum().item()
        #     return correct / total

        
        # Training loop for 10 epochs
        for epoch in range(10):
            model.train()
            epoch_loss = 0
            for src, tgt in train_loader:
                src, tgt = src.to(device), tgt.to(device)
                output = model(src, tgt[:, :-1])
                loss = criterion(output.reshape(-1, output.shape[-1]), tgt[:, 1:].reshape(-1))
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                epoch_loss += loss.item()

            val_char_acc, val_word_acc = evaluate()#evaluate(model, dev_loader)
            wandb.log({
                "epoch": epoch+1,
                "val_char_accuracy": val_char_acc,
                "val_word_accuracy": val_word_acc,
            })

# %% [markdown]
# # Step 9 : WandB sweep configuration

# %%
sweep_config = {
    'method': 'bayes',
    'name': 'hindi-transliteration-sweep',
    'metric': {
        'name': 'val_accuracy',
        'goal': 'maximize'
    },
    'parameters': {
        'embedding_dim': {'values': [16, 32, 64, 256]},
        'hidden_size': {'values': [16, 32, 64, 256]},
        'encoder_layers': {'values': [1, 2, 3]},
        'decoder_layers': {'values': [1, 2, 3]},
        'cell_type': {'values': ['RNN', 'GRU', 'LSTM']},
        'dropout': {'values': [0.2, 0.3]},
        'beam_size': {'values': [1, 3, 5]}, # Not used in decoding here, but swept
        'bidirectional': {'values': [True, False]}

    }
}

# Run sweep
sweep_id = wandb.sweep(sweep_config, project="dakshina-transliteration-hi")
#sweep_id= 'evp2r03p'
wandb.agent(sweep_id, function=train, count=100, project="dakshina-transliteration-hi", entity='snehalma23m020-iit-madras')
# Out:
# Create sweep with ID: gnn2a4fm
# Sweep URL: https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm
# wandb: Agent Starting Run: wazqszn7 with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: False
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 16
# wandb: 	encoder_layers: 1
# wandb: 	hidden_size: 64
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_094526-wazqszn7</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/wazqszn7' target="_blank">denim-sweep-1</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/wazqszn7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/wazqszn7</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▅▅▆▇▇▆▇██</td></tr><tr><td>val_word_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.28081</td></tr><tr><td>val_word_accuracy</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">denim-sweep-1</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/wazqszn7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/wazqszn7</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_094526-wazqszn7/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 6p7q1ie2 with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: True
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 16
# wandb: 	encoder_layers: 3
# wandb: 	hidden_size: 64
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_094623-6p7q1ie2</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6p7q1ie2' target="_blank">honest-sweep-2</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6p7q1ie2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6p7q1ie2</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▃▄▅▅▆▇▇██</td></tr><tr><td>val_word_accuracy</td><td>▁▁▂▂▂▃▅▆▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.55017</td></tr><tr><td>val_word_accuracy</td><td>0.02363</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">honest-sweep-2</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6p7q1ie2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6p7q1ie2</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_094623-6p7q1ie2/logs</code>
# wandb: Agent Starting Run: 5cycaj67 with config:
# wandb: 	beam_size: 1
# wandb: 	bidirectional: False
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 32
# wandb: 	encoder_layers: 2
# wandb: 	hidden_size: 256
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_094729-5cycaj67</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/5cycaj67' target="_blank">atomic-sweep-3</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/5cycaj67' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/5cycaj67</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▂▅▆▇▇██▇█</td></tr><tr><td>val_word_accuracy</td><td>▁▁▁▁▁▁█▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.33477</td></tr><tr><td>val_word_accuracy</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">atomic-sweep-3</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/5cycaj67' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/5cycaj67</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_094729-5cycaj67/logs</code>
# wandb: Agent Starting Run: kcarls8t with config:
# wandb: 	beam_size: 1
# wandb: 	bidirectional: True
# wandb: 	cell_type: GRU
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 256
# wandb: 	encoder_layers: 1
# wandb: 	hidden_size: 256
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_094825-kcarls8t</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/kcarls8t' target="_blank">misty-sweep-4</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/kcarls8t' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/kcarls8t</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▅▆▇██████</td></tr><tr><td>val_word_accuracy</td><td>▁▅▇▇██████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.83807</td></tr><tr><td>val_word_accuracy</td><td>0.32813</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">misty-sweep-4</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/kcarls8t' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/kcarls8t</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_094825-kcarls8t/logs</code>
# wandb: Agent Starting Run: ha8xhaiv with config:
# wandb: 	beam_size: 1
# wandb: 	bidirectional: True
# wandb: 	cell_type: LSTM
# wandb: 	decoder_layers: 2
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 32
# wandb: 	encoder_layers: 2
# wandb: 	hidden_size: 32
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_094936-ha8xhaiv</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ha8xhaiv' target="_blank">wild-sweep-5</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ha8xhaiv' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ha8xhaiv</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▂▄▅▅▆▇▇██</td></tr><tr><td>val_word_accuracy</td><td>▁▁▁▂▃▄▄▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.67644</td></tr><tr><td>val_word_accuracy</td><td>0.10028</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wild-sweep-5</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ha8xhaiv' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ha8xhaiv</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_094936-ha8xhaiv/logs</code>
# wandb: Agent Starting Run: 143pb3ob with config:
# wandb: 	beam_size: 1
# wandb: 	bidirectional: False
# wandb: 	cell_type: LSTM
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 64
# wandb: 	encoder_layers: 2
# wandb: 	hidden_size: 256
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_095047-143pb3ob</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/143pb3ob' target="_blank">light-sweep-6</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/143pb3ob' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/143pb3ob</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▆▇███████</td></tr><tr><td>val_word_accuracy</td><td>▁▄▆▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.85869</td></tr><tr><td>val_word_accuracy</td><td>0.3777</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">light-sweep-6</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/143pb3ob' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/143pb3ob</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_095047-143pb3ob/logs</code>
# wandb: Agent Starting Run: k46xwozv with config:
# wandb: 	beam_size: 5
# wandb: 	bidirectional: True
# wandb: 	cell_type: LSTM
# wandb: 	decoder_layers: 2
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 16
# wandb: 	encoder_layers: 1
# wandb: 	hidden_size: 16
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_095203-k46xwozv</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/k46xwozv' target="_blank">rare-sweep-7</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/k46xwozv' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/k46xwozv</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>val_word_accuracy</td><td>▁▂▂▃▃▅▅▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.45461</td></tr><tr><td>val_word_accuracy</td><td>0.00826</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rare-sweep-7</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/k46xwozv' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/k46xwozv</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_095203-k46xwozv/logs</code>
# wandb: Agent Starting Run: d0xsd8l8 with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: True
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 64
# wandb: 	encoder_layers: 1
# wandb: 	hidden_size: 32
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_095309-d0xsd8l8</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/d0xsd8l8' target="_blank">autumn-sweep-8</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/d0xsd8l8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/d0xsd8l8</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▃▄▄▅▅▆▇▇█</td></tr><tr><td>val_word_accuracy</td><td>▁▁▁▁▁▁▁▁▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.41998</td></tr><tr><td>val_word_accuracy</td><td>0.00092</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">autumn-sweep-8</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/d0xsd8l8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/d0xsd8l8</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_095309-d0xsd8l8/logs</code>
# wandb: Agent Starting Run: ye0x4d0r with config:
# wandb: 	beam_size: 5
# wandb: 	bidirectional: False
# wandb: 	cell_type: GRU
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 32
# wandb: 	encoder_layers: 1
# wandb: 	hidden_size: 256
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_095405-ye0x4d0r</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ye0x4d0r' target="_blank">drawn-sweep-9</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ye0x4d0r' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ye0x4d0r</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▅▇▇██████</td></tr><tr><td>val_word_accuracy</td><td>▁▄▆▇▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.84163</td></tr><tr><td>val_word_accuracy</td><td>0.33639</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">drawn-sweep-9</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ye0x4d0r' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/ye0x4d0r</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_095405-ye0x4d0r/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 7pd2gdqu with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: True
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 64
# wandb: 	encoder_layers: 2
# wandb: 	hidden_size: 256
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_095512-7pd2gdqu</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/7pd2gdqu' target="_blank">vocal-sweep-10</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/7pd2gdqu' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/7pd2gdqu</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▃▆▆▇█████</td></tr><tr><td>val_word_accuracy</td><td>▁▃▅▆▆█▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.71823</td></tr><tr><td>val_word_accuracy</td><td>0.15076</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vocal-sweep-10</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/7pd2gdqu' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/7pd2gdqu</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_095512-7pd2gdqu/logs</code>
# wandb: Agent Starting Run: 0cgpziud with config:
# wandb: 	beam_size: 1
# wandb: 	bidirectional: True
# wandb: 	cell_type: GRU
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 256
# wandb: 	encoder_layers: 3
# wandb: 	hidden_size: 16
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_095638-0cgpziud</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/0cgpziud' target="_blank">pretty-sweep-11</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/0cgpziud' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/0cgpziud</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>val_word_accuracy</td><td>▁▂▁▂▄▄▄▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.54067</td></tr><tr><td>val_word_accuracy</td><td>0.02134</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pretty-sweep-11</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/0cgpziud' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/0cgpziud</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_095638-0cgpziud/logs</code>
# wandb: Agent Starting Run: p31i7rys with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: False
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 2
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 32
# wandb: 	encoder_layers: 3
# wandb: 	hidden_size: 256
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_095744-p31i7rys</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/p31i7rys' target="_blank">denim-sweep-12</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/p31i7rys' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/p31i7rys</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▄▄▆▆▇▇█▇█</td></tr><tr><td>val_word_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.30954</td></tr><tr><td>val_word_accuracy</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">denim-sweep-12</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/p31i7rys' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/p31i7rys</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_095744-p31i7rys/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: q814exvi with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: True
# wandb: 	cell_type: LSTM
# wandb: 	decoder_layers: 3
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 256
# wandb: 	encoder_layers: 3
# wandb: 	hidden_size: 16
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_095900-q814exvi</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/q814exvi' target="_blank">dark-sweep-13</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/q814exvi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/q814exvi</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▄▄▅▅▆▇▇██</td></tr><tr><td>val_word_accuracy</td><td>▁▁▂▄▄▄▆▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.4903</td></tr><tr><td>val_word_accuracy</td><td>0.00665</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dark-sweep-13</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/q814exvi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/q814exvi</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_095900-q814exvi/logs</code>
# wandb: Agent Starting Run: rraw3pu2 with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: False
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 64
# wandb: 	encoder_layers: 1
# wandb: 	hidden_size: 64
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_100017-rraw3pu2</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/rraw3pu2' target="_blank">zesty-sweep-14</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/rraw3pu2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/rraw3pu2</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▃▅▆▆▇▇███</td></tr><tr><td>val_word_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.2877</td></tr><tr><td>val_word_accuracy</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">zesty-sweep-14</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/rraw3pu2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/rraw3pu2</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_100017-rraw3pu2/logs</code>
# wandb: Agent Starting Run: m3fhulb6 with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: False
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 32
# wandb: 	encoder_layers: 1
# wandb: 	hidden_size: 32
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_100108-m3fhulb6</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/m3fhulb6' target="_blank">vague-sweep-15</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/m3fhulb6' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/m3fhulb6</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▄▆▇▇▇▇▇██</td></tr><tr><td>val_word_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.26798</td></tr><tr><td>val_word_accuracy</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vague-sweep-15</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/m3fhulb6' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/m3fhulb6</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_100108-m3fhulb6/logs</code>
# wandb: Agent Starting Run: 7bzx8hiu with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: False
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 2
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 256
# wandb: 	encoder_layers: 1
# wandb: 	hidden_size: 32
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_100204-7bzx8hiu</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/7bzx8hiu' target="_blank">deft-sweep-16</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
# ...
# Find logs at: <code>./wandb/run-20250518_113656-crlrrrdo/logs</code>
# wandb: Agent Starting Run: pc4c8112 with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: False
# wandb: 	cell_type: GRU
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 16
# wandb: 	encoder_layers: 2
# wandb: 	hidden_size: 16
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_113808-pc4c8112</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pc4c8112' target="_blank">zesty-sweep-96</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pc4c8112' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pc4c8112</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▄▅▅▆▆▇▇██</td></tr><tr><td>val_word_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.36248</td></tr><tr><td>val_word_accuracy</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">zesty-sweep-96</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pc4c8112' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pc4c8112</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_113808-pc4c8112/logs</code>
# wandb: Agent Starting Run: b4nzmhae with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: True
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 64
# wandb: 	encoder_layers: 3
# wandb: 	hidden_size: 32
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_113904-b4nzmhae</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/b4nzmhae' target="_blank">decent-sweep-97</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/b4nzmhae' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/b4nzmhae</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▃▅▆▆▆▇▇██</td></tr><tr><td>val_word_accuracy</td><td>▅▁▁▁▁▁▁█▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.41021</td></tr><tr><td>val_word_accuracy</td><td>0.00023</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">decent-sweep-97</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/b4nzmhae' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/b4nzmhae</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_113904-b4nzmhae/logs</code>
# wandb: Agent Starting Run: pim62ra4 with config:
# wandb: 	beam_size: 1
# wandb: 	bidirectional: False
# wandb: 	cell_type: LSTM
# wandb: 	decoder_layers: 3
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 16
# wandb: 	encoder_layers: 3
# wandb: 	hidden_size: 256
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_114004-pim62ra4</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pim62ra4' target="_blank">happy-sweep-98</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pim62ra4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pim62ra4</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▃▅▇▇█████</td></tr><tr><td>val_word_accuracy</td><td>▁▁▂▅▆▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.85915</td></tr><tr><td>val_word_accuracy</td><td>0.37816</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">happy-sweep-98</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pim62ra4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/pim62ra4</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_114004-pim62ra4/logs</code>
# wandb: Agent Starting Run: 6artny3a with config:
# wandb: 	beam_size: 5
# wandb: 	bidirectional: False
# wandb: 	cell_type: RNN
# wandb: 	decoder_layers: 2
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 16
# wandb: 	encoder_layers: 3
# wandb: 	hidden_size: 256
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_114216-6artny3a</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6artny3a' target="_blank">major-sweep-99</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6artny3a' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6artny3a</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▄▅▅▅▇████</td></tr><tr><td>val_word_accuracy</td><td>▁▁▁▁▁▁▁▁▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.29704</td></tr><tr><td>val_word_accuracy</td><td>0.00023</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">major-sweep-99</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6artny3a' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/6artny3a</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_114216-6artny3a/logs</code>
# wandb: Agent Starting Run: o7g2wssh with config:
# wandb: 	beam_size: 3
# wandb: 	bidirectional: True
# wandb: 	cell_type: GRU
# wandb: 	decoder_layers: 1
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 64
# wandb: 	encoder_layers: 3
# wandb: 	hidden_size: 256
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_114328-o7g2wssh</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/o7g2wssh' target="_blank">volcanic-sweep-100</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/sweeps/gnn2a4fm</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/o7g2wssh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/o7g2wssh</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_char_accuracy</td><td>▁▅▆▇███▇██</td></tr><tr><td>val_word_accuracy</td><td>▁▅▆▇███▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>val_char_accuracy</td><td>0.85249</td></tr><tr><td>val_word_accuracy</td><td>0.35911</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">volcanic-sweep-100</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/o7g2wssh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi/runs/o7g2wssh</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-transliteration-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_114328-o7g2wssh/logs</code>

# %% [markdown]
# # Step 10:  The best hyperparametrs obtained with the help of Wandb are :
# # beam_size: 1
# # bidirectional: False
# # cell_type: LSTM
# # decoder_layers: 3
# # dropout: 0.3
# # embedding_dim:256
# # encoder_layers: 2
# # hidden_size: 256

# %% [markdown]
# # Step 11 : Now training the model with best hyperparameters and evaluate on test set

# %% [markdown]
# # note : beam size = 1

# %%
# Load Latin-Devanagari pairs from each file
train_pairs = load_dakshina_pairs(train_path)
dev_pairs   = load_dakshina_pairs(dev_path)
test_pairs  = load_dakshina_pairs(test_path)

# Build vocabularies
input_vocab, target_vocab = build_vocab(train_pairs)

# Create character-to-index mappings
input_char2idx  = {c:i for i,c in enumerate(input_vocab)}
target_char2idx = {c:i for i,c in enumerate(target_vocab)}
target_idx2char = {i:c for c,i in target_char2idx.items()}

# Special token indices
PAD_IDX = target_char2idx["<pad>"]
EOS_IDX = target_char2idx["<eos>"]

# Define max sequence lengths (+2 for <sos> and <eos>)
max_in  = max(len(s) for s,_ in train_pairs) + 2
max_out = max(len(t) for _,t in train_pairs) + 2

# Create PyTorch datasets for training, validation and test
train_ds = TransliterationDataset(train_pairs, input_char2idx, target_char2idx, max_in, max_out)
dev_ds   = TransliterationDataset(dev_pairs,   input_char2idx, target_char2idx, max_in, max_out)
test_ds  = TransliterationDataset(test_pairs,  input_char2idx, target_char2idx, max_in, max_out)

train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
dev_loader   = DataLoader(dev_ds,   batch_size=64)
test_loader  = DataLoader(test_ds,  batch_size=64)

# Instantiate the best model —
# best hyperparameters
best_hparams = dict(
    embedding_dim  = 256,hidden_size = 256, encoder_layers = 2, decoder_layers = 3, rnn_type = "LSTM", dropout = 0.3, bidirectional  = False)

 #  Seq2Seq model using best hyperparameters found from sweep
model = Seq2Seq(
    input_vocab_size = len(input_vocab),
    target_vocab_size= len(target_vocab),
    embedding_dim    = best_hparams["embedding_dim"],
    hidden_size      = best_hparams["hidden_size"],
    encoder_layers   = best_hparams["encoder_layers"],
    decoder_layers   = best_hparams["decoder_layers"],
    rnn_type         = best_hparams["rnn_type"],
    dropout          = best_hparams["dropout"],
    bidirectional    = best_hparams["bidirectional"]
).to(device)

# Define optimiser and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss(ignore_index=PAD_IDX)

# Computes exact-match word-level accuracy over a given data split
def evaluate_split(loader):
    model.eval()
    corr, total = 0, 0
    with torch.no_grad():
        for src, tgt in loader:
            src, tgt = src.to(device), tgt.to(device)

            # Forward pass through model
            logits = model(src, tgt[:, :-1])
            preds  = torch.argmax(logits, dim=-1)
            B, T    = preds.size()
            
            for i in range(B):
                # Convert target sequence to string
                gold_seq = tgt[i,1:].tolist()
                if EOS_IDX in gold_seq:
                    gold_seq = gold_seq[:gold_seq.index(EOS_IDX)]
                gold = "".join(target_idx2char[x] for x in gold_seq)
                # extract pred string
                p_seq = preds[i].tolist()
                if EOS_IDX in p_seq:
                    p_seq = p_seq[:p_seq.index(EOS_IDX)]
                pred = "".join(target_idx2char[x] for x in p_seq)
                # tally
                corr  += (pred == gold)
                total += 1
    return corr/total



# Training + validation loop —
num_epochs = 10
best_dev_acc = 0.0

for epoch in range(1, num_epochs+1):
    model.train()
    running_loss = 0.0

    for src, tgt in train_loader:
        src, tgt = src.to(device), tgt.to(device)

        # Forward pass
        logits   = model(src, tgt[:, :-1])
        loss     = criterion(logits.reshape(-1, logits.size(-1)),tgt[:,1:].reshape(-1))

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    dev_acc = evaluate_split(dev_loader)

    print(f"Epoch {epoch:2d}  Train Loss: {avg_train_loss:.4f}  |  Dev Acc: {dev_acc:.4f}")

    # save best model
    if dev_acc > best_dev_acc:
        best_dev_acc = dev_acc
        torch.save(model.state_dict(), "best_seq2seq.pt")

#  Final test evaluation —
model.load_state_dict(torch.load("best_seq2seq.pt"))
test_acc = evaluate_split(test_loader)
print(f"\nFinal Test Exact‐Match Acc: {test_acc:.4f}")
# Out:
# Epoch  1  Train Loss: 2.5220  |  Dev Acc: 0.0190
# Epoch  2  Train Loss: 1.0691  |  Dev Acc: 0.2150
# Epoch  3  Train Loss: 0.6484  |  Dev Acc: 0.3040
# Epoch  4  Train Loss: 0.5142  |  Dev Acc: 0.3309
# Epoch  5  Train Loss: 0.4386  |  Dev Acc: 0.3504
# Epoch  6  Train Loss: 0.3879  |  Dev Acc: 0.3639
# Epoch  7  Train Loss: 0.3483  |  Dev Acc: 0.3871
# Epoch  8  Train Loss: 0.3165  |  Dev Acc: 0.3816
# Epoch  9  Train Loss: 0.2897  |  Dev Acc: 0.3834
# Epoch 10  Train Loss: 0.2665  |  Dev Acc: 0.3899
#
# Final Test Exact‐Match Acc: 0.3994

# %% [markdown]
# # Step 12 : Storing predictions on the entire test set

# %%
# Ensure the output folder exists
os.makedirs("predictions_vanilla", exist_ok=True)

# Build a DataFrame 
df = pd.DataFrame(predictions, columns=["latin", "gold", "predicted"])

# Write out as CSV
csv_path = os.path.join("predictions_vanilla", "predictions.csv")
df.to_csv(csv_path, index=False, encoding="utf-8")
print(f"→ Wrote all predictions to {csv_path}")

# write out as TSV 
tsv_path = os.path.join("predictions_vanilla", "predictions.tsv")
df.to_csv(tsv_path, sep="\t", index=False, encoding="utf-8")
print(f"→ Wrote all predictions to {tsv_path}")
# Out:
# → Wrote all predictions to predictions_vanilla/predictions.csv
# → Wrote all predictions to predictions_vanilla/predictions.tsv

# %% [markdown]
# # Step 13 : displaying the Transliteration grid

# %%
try:
    predictions
except NameError:
    df = pd.read_csv("predictions_vanilla/predictions.tsv", sep="\t", encoding="utf-8")
    predictions = list(zip(df['latin'], df['gold'], df['predicted']))


# format of the grid
def display_colored_prediction_grid(predictions, n=20):
    """
    Display a styled table with model predictions vs ground truth.
    Args:
        predictions (list of tuples): (latin_input, reference_output, predicted_output)
        n (int): number of rows to show
    """
    df = pd.DataFrame(predictions[:n], columns=["Latin", "Reference", "Predicted"])

    html = '<h3> Hindi Transliteration: Prediction Grid</h3>'
    html += """
    <style>
        table.pred-table {
            border-collapse: collapse;
            font-family: monospace;
            margin: 10px 0;
        }
        table.pred-table th, table.pred-table td {
            border: 1px solid #ccc;
            padding: 6px 14px;
            text-align: center;
        }
    </style>
    """
    html += '<table class="pred-table">'
    html += '<thead><tr><th>#</th><th>Latin Input</th><th>Predicted</th><th>Reference</th><th>Status</th></tr></thead><tbody>'

    for i, row in df.iterrows():
        match        = row["Predicted"] == row["Reference"]
        bg_color     = "#d4edda" if match else "#f8d7da"
        border_color = "#28a745" if match else "#dc3545"
        status_icon  = "CORRECT" if match else "INCORRECT"

        html += f'''
        <tr style="background-color: {bg_color}; border: 2px solid {border_color};">
            <td>{i+1}</td>
            <td><b>{row["Latin"]}</b></td>
            <td style="border: 2px solid {border_color};">{row["Predicted"]}</td>
            <td style="border: 2px solid {border_color};">{row["Reference"]}</td>
            <td>{status_icon}</td>
        </tr>
        '''

    html += '</tbody></table>'
    display(HTML(html))




# show the 20 examples
display_colored_prediction_grid(predictions, n=20)
# Out:
# <h3> Hindi Transliteration: Prediction Grid</h3>
#     <style>
#         table.pred-table {
#             border-collapse: collapse;
#             font-family: monospace;
#             margin: 10px 0;
#         }
#         table.pred-table th, table.pred-table td {
#             border: 1px solid #ccc;
#             padding: 6px 14px;
#             text-align: center;
#         }
#     </style>
#     <table class="pred-table"><thead><tr><th>#</th><th>Latin Input</th><th>Predicted</th><th>Reference</th><th>Status</th></tr></thead><tbody>
#         <tr style="background-color: #d4edda; border: 2px solid #28a745;">
#             <td>1</td>
#             <td><b>ank</b></td>
#             <td style="border: 2px solid #28a745;">अंक</td>
#             <td style="border: 2px solid #28a745;">अंक</td>
#             <td>CORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>2</td>
#             <td><b>anka</b></td>
#             <td style="border: 2px solid #dc3545;">अंका</td>
#             <td style="border: 2px solid #dc3545;">अंक</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>3</td>
#             <td><b>ankit</b></td>
#             <td style="border: 2px solid #dc3545;">अनकित</td>
#             <td style="border: 2px solid #dc3545;">अंकित</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>4</td>
#             <td><b>anakon</b></td>
#             <td style="border: 2px solid #dc3545;">अनकों</td>
#             <td style="border: 2px solid #dc3545;">अंकों</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>5</td>
#             <td><b>ankhon</b></td>
#             <td style="border: 2px solid #dc3545;">अंखों</td>
#             <td style="border: 2px solid #dc3545;">अंकों</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #d4edda; border: 2px solid #28a745;">
#             <td>6</td>
#             <td><b>ankon</b></td>
#             <td style="border: 2px solid #28a745;">अंकों</td>
#             <td style="border: 2px solid #28a745;">अंकों</td>
#             <td>CORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>7</td>
#             <td><b>angkor</b></td>
#             <td style="border: 2px solid #dc3545;">अंगोकक</td>
#             <td style="border: 2px solid #dc3545;">अंकोर</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>8</td>
#             <td><b>ankor</b></td>
#             <td style="border: 2px solid #dc3545;">अनकोर</td>
#             <td style="border: 2px solid #dc3545;">अंकोर</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #d4edda; border: 2px solid #28a745;">
#             <td>9</td>
#             <td><b>angaarak</b></td>
#             <td style="border: 2px solid #28a745;">अंगारक</td>
#             <td style="border: 2px solid #28a745;">अंगारक</td>
#             <td>CORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>10</td>
#             <td><b>angarak</b></td>
#             <td style="border: 2px solid #dc3545;">अंगररक</td>
#             <td style="border: 2px solid #dc3545;">अंगारक</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>11</td>
#             <td><b>angraji</b></td>
#             <td style="border: 2px solid #dc3545;">अगग्रजीी</td>
#             <td style="border: 2px solid #dc3545;">अंग्रज़ी</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>12</td>
#             <td><b>angreji</b></td>
#             <td style="border: 2px solid #dc3545;">अगग्रजीी</td>
#             <td style="border: 2px solid #dc3545;">अंग्रज़ी</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>13</td>
#             <td><b>angrzi</b></td>
#             <td style="border: 2px solid #dc3545;">अंग्रजीी</td>
#             <td style="border: 2px solid #dc3545;">अंग्रज़ी</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #d4edda; border: 2px solid #28a745;">
#             <td>14</td>
#             <td><b>antah</b></td>
#             <td style="border: 2px solid #28a745;">अंतः</td>
#             <td style="border: 2px solid #28a745;">अंतः</td>
#             <td>CORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>15</td>
#             <td><b>antaha</b></td>
#             <td style="border: 2px solid #dc3545;">अंतःा</td>
#             <td style="border: 2px solid #dc3545;">अंतः</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #d4edda; border: 2px solid #28a745;">
#             <td>16</td>
#             <td><b>antarmukh</b></td>
#             <td style="border: 2px solid #28a745;">अंतर्मुख</td>
#             <td style="border: 2px solid #28a745;">अंतर्मुख</td>
#             <td>CORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>17</td>
#             <td><b>antmurkh</b></td>
#             <td style="border: 2px solid #dc3545;">अंतरममुख</td>
#             <td style="border: 2px solid #dc3545;">अंतर्मुख</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #d4edda; border: 2px solid #28a745;">
#             <td>18</td>
#             <td><b>antrmukh</b></td>
#             <td style="border: 2px solid #28a745;">अंतर्मुख</td>
#             <td style="border: 2px solid #28a745;">अंतर्मुख</td>
#             <td>CORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>19</td>
#             <td><b>andrabee</b></td>
#             <td style="border: 2px solid #dc3545;">अंद्रबबी</td>
#             <td style="border: 2px solid #dc3545;">अंद्राबी</td>
#             <td>INCORRECT</td>
#         </tr>
#
#         <tr style="background-color: #f8d7da; border: 2px solid #dc3545;">
#             <td>20</td>
#             <td><b>andrabi</b></td>
#             <td style="border: 2px solid #dc3545;">अंद्रबबी</td>
#             <td style="border: 2px solid #dc3545;">अंद्राबी</td>
#             <td>INCORRECT</td>
#         </tr>
#         </tbody></table>
