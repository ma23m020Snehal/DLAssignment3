# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/hindi-scipt/NotoSansDevanagari-VariableFont_wdth,wght.ttf
# /kaggle/input/hindi-scipt/README.txt
# /kaggle/input/hindi-scipt/OFL.txt
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_ExtraCondensed-ExtraBold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_SemiCondensed-Medium.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_ExtraCondensed-Bold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_SemiCondensed-Black.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_Condensed-Black.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari-Bold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari-Regular.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_ExtraCondensed-Light.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_ExtraCondensed-Black.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_SemiCondensed-Thin.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari-ExtraLight.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_Condensed-ExtraLight.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_SemiCondensed-Regular.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_Condensed-ExtraBold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari-Black.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_Condensed-Bold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_SemiCondensed-SemiBold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_ExtraCondensed-ExtraLight.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari-SemiBold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_Condensed-Regular.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_ExtraCondensed-SemiBold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari-Thin.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_SemiCondensed-ExtraBold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_SemiCondensed-Bold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_Condensed-Light.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_ExtraCondensed-Medium.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_ExtraCondensed-Regular.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_Condensed-Medium.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari-Light.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_Condensed-SemiBold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_SemiCondensed-ExtraLight.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_ExtraCondensed-Thin.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari-ExtraBold.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari-Medium.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_SemiCondensed-Light.ttf
# /kaggle/input/hindi-scipt/static/NotoSansDevanagari_Condensed-Thin.ttf
# /kaggle/input/snehal/hi.translit.sampled.dev.tsv
# /kaggle/input/snehal/hi.translit.sampled.test.tsv
# /kaggle/input/snehal/hi.translit.sampled.train.tsv

# %% [markdown]
# # Step 1 : Setting up the wandb

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("wandb")

# %%
import wandb
wandb.login(key=secret_value_0)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ma23m020 (snehalma23m020-iit-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Step 2 : importing the important libraries

# %%
import os, random, time
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import wandb
from pathlib import Path
from IPython.display import HTML, display
import matplotlib.font_manager as fm
import pathlib
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from math import ceil

# %% [markdown]
# # Step 3 : set the seed for reproducibility and setting up the device

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

set_seed()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Step 4 : Loading the dataset ( Dakshina dataset)

# %%
def load_dakshina_pairs(path):    
    df = (
        pd.read_csv(path,sep="\t",names=["native", "latin", "count"],
            dtype={"native": str, "latin": str, "count": str}  # force strings
        )
        .dropna(subset=["native", "latin"])       # <-- NEW: keep only complete rows
    )

    # strip any stray whitespace
    df["native"] = df["native"].str.strip()
    df["latin"]  = df["latin"].str.strip()

    # remove empty strings (after strip)
    df = df[(df["native"] != "") & (df["latin"] != "")]
    return list(zip(df["latin"], df["native"]))

# %% [markdown]
# # Step 5 : The build_vocab function constructs character-level vocabularies for source and target scripts.
# # The TransliterationDataset prepares source-target sequence pairs.

# %%
# Building vocab
def build_vocab(pairs, specials=None):
    specials = specials or ["<pad>", "<sos>", "<eos>", "<unk>"]
    latin  = [src for src, _ in pairs if isinstance(src, str)]
    deva   = [tgt for _, tgt in pairs if isinstance(tgt, str)]
    input_chars  = sorted(set("".join(latin)))
    target_chars = sorted(set("".join(deva)))
    return specials + input_chars, specials + target_chars


class TransliterationDataset(Dataset):
    def __init__(self, pairs, in2idx, out2idx, max_in, max_out):
        self.pairs, self.in2idx, self.out2idx = pairs, in2idx, out2idx
        self.max_in, self.max_out = max_in, max_out
        self.pad_i, self.pad_o = in2idx["<pad>"], out2idx["<pad>"]

    def __len__(self): return len(self.pairs)

    def __getitem__(self, idx):
        latin, deva = self.pairs[idx]

        src = [self.in2idx["<sos>"]]  + [self.in2idx.get(c, self.in2idx["<unk>"])  for c in latin] + [self.in2idx["<eos>"]]
        tgt = [self.out2idx["<sos>"]] + [self.out2idx.get(c, self.out2idx["<unk>"]) for c in deva]  + [self.out2idx["<eos>"]]

        # truncate then pad
        src = src[:self.max_in]  + [self.pad_i] * (self.max_in  - len(src))
        tgt = tgt[:self.max_out] + [self.pad_o] * (self.max_out - len(tgt))

        return torch.tensor(src), torch.tensor(tgt)

# %% [markdown]
# # Step 6 : Bahdanau Attention

# %%
class BahdanauAttention(nn.Module):
    def __init__(self, enc_dim, dec_dim):
        super().__init__()
        
        # linear projections for encoder outputs and decoder hidden
        self.W_enc = nn.Linear(enc_dim, dec_dim, bias=False)
        self.W_dec = nn.Linear(dec_dim, dec_dim, bias=False)
        self.v     = nn.Linear(dec_dim, 1, bias=False)   # scoring vector


    def forward(self, dec_hidden, enc_outputs, mask):
        # dec_hidden: [B, dec_dim]   enc_outputs: [B, S, enc_dim]  mask: [B, S]
        score = self.v(torch.tanh(self.W_enc(enc_outputs) + self.W_dec(dec_hidden).unsqueeze(1))).squeeze(-1)
        score.masked_fill_(mask == 0, -1e9)
        attn = torch.softmax(score, dim=1)                       # [B, S]
        ctx  = torch.bmm(attn.unsqueeze(1), enc_outputs).squeeze(1)  # [B, enc_dim]
        return ctx, attn                  #  context, weights

# %% [markdown]
# # Step 7 :  Seq2Seq with Bahdanau Attention

# %%
class Seq2SeqAttention(nn.Module):
    def __init__(self, in_vocab, out_vocab, emb_dim, hid_dim,rnn_type="LSTM", dropout=0.3, bidir=False, pad_idx=0,enc_layers=1, dec_layers=1):
        super().__init__()
        rnn_cls = getattr(nn, rnn_type)
        self.rnn_type, self.pad_idx, self.bidir = rnn_type, pad_idx, bidir
        self.dir_mult = 2 if bidir else 1
        self.dec_layers = dec_layers

        # Embeddings
        self.src_emb = nn.Embedding(in_vocab, emb_dim, padding_idx=pad_idx)
        self.tgt_emb = nn.Embedding(out_vocab, emb_dim, padding_idx=pad_idx)

        # Encoder
        self.encoder = rnn_cls(emb_dim, hid_dim, enc_layers, batch_first=True, bidirectional=bidir, dropout=dropout if enc_layers > 1 else 0)

        # Bridge for bidirectional 
        if bidir or enc_layers != dec_layers:
            self.bridge = nn.Linear(hid_dim * self.dir_mult, hid_dim)

        # Attention
        self.attn = BahdanauAttention(hid_dim * self.dir_mult, hid_dim)

        # Decoder (input = [emb | ctx])
        self.decoder = rnn_cls(emb_dim + hid_dim * self.dir_mult,hid_dim, dec_layers, batch_first=True,dropout=dropout if dec_layers > 1 else 0)

        self.fc_out = nn.Linear(hid_dim, out_vocab)
        self.dropout = nn.Dropout(dropout)

    # ----- helper to initialise decoder hidden -------------
    def _init_dec_state(self, enc_hidden):
        if self.rnn_type == "LSTM":
            h, c = enc_hidden
        else:
            h = enc_hidden

        if self.bidir:
            if self.rnn_type == "LSTM":
                h = torch.cat([h[-2], h[-1]], dim=1)
                c = torch.cat([c[-2], c[-1]], dim=1)
                h = self.bridge(h).unsqueeze(0)
                c = self.bridge(c).unsqueeze(0)
                h = h.repeat(self.dec_layers, 1, 1)
                c = c.repeat(self.dec_layers, 1, 1)
                return (h, c)
            else:
                h = torch.cat([h[-2], h[-1]], dim=1)
                h = self.bridge(h).unsqueeze(0)
                h = h.repeat(self.dec_layers, 1, 1)
                return h
        else:
            # same #layers; copy last layer out
            if self.rnn_type == "LSTM":
                h = h[-1:].repeat(self.dec_layers,1,1)
                c = c[-1:].repeat(self.dec_layers,1,1)
                return (h,c)
            else:
                h = h[-1:].repeat(self.dec_layers,1,1)
                return h


    def forward(self, src, tgt, teacher_forcing=0.5):
        B, S = src.size()
        _, T = tgt.size()
        mask = (src != self.pad_idx)                # [B,S]

        # ---- encode ----
        enc_outs, enc_hidden = self.encoder(self.dropout(self.src_emb(src)))
        dec_hidden = self._init_dec_state(enc_hidden)

        # ---- decode ----
        outputs = torch.zeros(B, T, self.fc_out.out_features, device=src.device)
        input_t = tgt[:, 0]                         # <sos>

        for t in range(1, T):
            emb_t = self.dropout(self.tgt_emb(input_t)).unsqueeze(1)  # [B,1,E]
            # last-layer hidden for attention
            dec_last = dec_hidden[0][-1] if self.rnn_type=="LSTM" else dec_hidden[-1]  # [B, H]
            ctx, _   = self.attn(dec_last, enc_outs, mask)

            rnn_inp  = torch.cat([emb_t, ctx.unsqueeze(1)], dim=2)    # [B,1,E+H]
            dec_out, dec_hidden = self.decoder(rnn_inp, dec_hidden)
            pred = self.fc_out(dec_out.squeeze(1))                    # [B, V]
            outputs[:, t] = pred

            teacher = torch.rand(1).item() < teacher_forcing
            input_t = tgt[:, t] if teacher else pred.argmax(1)

        return outputs   # logits

# %% [markdown]
# # Step 8 : Training the model

# %%
def evaluate(model, loader, idx2char, eos_idx, pad_idx):
    model.eval()
    corr_chars = tot_chars = corr_words = tot_words = 0
    with torch.no_grad():
        for src, tgt in loader:
            src, tgt = src.to(device), tgt.to(device)
            logits = model(src, tgt, teacher_forcing=0)          # no TF in eval
            pred  = logits.argmax(-1)[:,1:]      # drop <sos> column
            gold  = tgt[:,1:]

            mask = gold != pad_idx
            corr_chars += (pred == gold).masked_select(mask).sum().item()
            tot_chars  += mask.sum().item()

            # word-level exact match
            for p, g in zip(pred, gold):
                p = p.tolist()
                g = g.tolist()
                if eos_idx in p: p = p[:p.index(eos_idx)]
                if eos_idx in g: g = g[:g.index(eos_idx)]
                if "".join(idx2char[i] for i in p) == "".join(idx2char[i] for i in g):
                    corr_words += 1
                tot_words += 1
    return corr_chars/tot_chars, corr_words/tot_words

# %% [markdown]
# # Step 9 : Wandb training function

# %%
def train_wandb(config=None):
    with wandb.init(config=config):
        cfg = wandb.config

        # data paths 
        root = "/kaggle/input/snehal"
        train_pairs = load_dakshina_pairs(os.path.join(root,"hi.translit.sampled.train.tsv"))
        dev_pairs   = load_dakshina_pairs(os.path.join(root,"hi.translit.sampled.dev.tsv"))

        # build vocabs
        in_vocab, out_vocab = build_vocab(train_pairs)
        in2idx  = {c:i for i,c in enumerate(in_vocab)}
        out2idx = {c:i for i,c in enumerate(out_vocab)}
        idx2out = {i:c for c,i in out2idx.items()}
        PAD, EOS = out2idx["<pad>"], out2idx["<eos>"]

        max_in  = max(len(p[0]) for p in train_pairs)+2
        max_out = max(len(p[1]) for p in train_pairs)+2

        train_ds = TransliterationDataset(train_pairs,in2idx,out2idx,max_in,max_out)
        dev_ds   = TransliterationDataset(dev_pairs,  in2idx,out2idx,max_in,max_out)
        train_ld = DataLoader(train_ds,batch_size=cfg.batch_size,shuffle=True)
        dev_ld   = DataLoader(dev_ds,  batch_size=cfg.batch_size)

        # --- model ---
        # model = Seq2SeqAttention(
        #     in_vocab=len(in_vocab),
        #     out_vocab=len(out_vocab),
        #     emb_dim=cfg.emb_dim,
        #     hid_dim=cfg.hid_dim,
        #     rnn_type=cfg.rnn_type,
        #     dropout=cfg.dropout,
        #     bidir=cfg.bidir,
        #     pad_idx=PAD,
        #     enc_layers=1,
        #     dec_layers=1
        # ).to(device)


        # build model
        model = Seq2SeqAttention(in_vocab=len(in_vocab),out_vocab=len(out_vocab),emb_dim=cfg.emb_dim,hid_dim=cfg.hid_dim,rnn_type=cfg.cell_type,dropout=cfg.dropout,bidir=cfg.bidir,pad_idx=PAD,enc_layers=1,dec_layers=1).to(device)

        # --- optimiser / loss ---
        opt = optim.Adam(model.parameters(), lr=cfg.lr)
        criterion = nn.CrossEntropyLoss(ignore_index=PAD)

        # --- training loop ---
        for epoch in range(1, cfg.epochs+1):
            model.train()
            epoch_loss = 0
            for src, tgt in train_ld:
                src, tgt = src.to(device), tgt.to(device)
                logits = model(src, tgt, teacher_forcing=cfg.tf_ratio)
                loss   = criterion(logits[:,1:].reshape(-1, logits.size(-1)),
                                   tgt[:,1:].reshape(-1))
                opt.zero_grad(); loss.backward(); opt.step()
                epoch_loss += loss.item()

            char_acc, word_acc = evaluate(model, dev_ld, idx2out, EOS, PAD)
            wandb.log({
                "epoch": epoch,
                "train_loss": epoch_loss/len(train_ld),
                "val_char_acc": char_acc,
                "val_word_acc": word_acc
            })

# %% [markdown]
# # Step 10 : Sweep Configuration & Launch

# %%
sweep_cfg = {
    "method": "bayes",
    "metric": {"name": "val_char_acc", "goal": "maximize"},
    "parameters": {
        "batch_size": {"values": [32,64]},
        "emb_dim":    {"values": [16,32, 64, 128, 256]},
        "hid_dim":    {"values": [16,32, 64, 128, 256]},
        "cell_type":  {"values": ["RNN", "GRU", "LSTM"]},
        "beam_size":  {"values": [1, 3, 5]},
        "dropout":    {"values": [0.2, 0.3]},
        "bidir":      {"values": [True, False]},
        "lr":         {"values": [1e-3, 5e-4]},
        "tf_ratio":   {"values": [1]},
        "epochs":     {"value": 10}
    }
}

sweep_id = wandb.sweep(sweep_cfg, project="dakshina-translit-hi")
wandb.agent(sweep_id, function=train_wandb, count=57,project="dakshina-translit-hi")
# Out:
# Create sweep with ID: i6h8vkm4
# Sweep URL: https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4
# wandb: Agent Starting Run: ddfchk4s with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hid_dim: 128
# wandb: 	lr: 0.0005
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_105900-ddfchk4s</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ddfchk4s' target="_blank">rural-sweep-1</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ddfchk4s' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ddfchk4s</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▆▆▇▇▇███</td></tr><tr><td>val_word_acc</td><td>▁▄▆▆▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.34979</td></tr><tr><td>val_char_acc</td><td>0.70804</td></tr><tr><td>val_word_acc</td><td>0.38022</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rural-sweep-1</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ddfchk4s' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ddfchk4s</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_105900-ddfchk4s/logs</code>
# wandb: Agent Starting Run: 7znd2k8v with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 1
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 32
# wandb: 	epochs: 10
# wandb: 	hid_dim: 32
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_111014-7znd2k8v</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7znd2k8v' target="_blank">upbeat-sweep-2</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7znd2k8v' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7znd2k8v</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▄▂▂▂▁▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▆▇▇▇█████</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.61287</td></tr><tr><td>val_char_acc</td><td>0.65883</td></tr><tr><td>val_word_acc</td><td>0.29578</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">upbeat-sweep-2</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7znd2k8v' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7znd2k8v</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_111014-7znd2k8v/logs</code>
# wandb: Agent Starting Run: ngxrpi3e with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 5
# wandb: 	bidir: True
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 32
# wandb: 	epochs: 10
# wandb: 	hid_dim: 64
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_112117-ngxrpi3e</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ngxrpi3e' target="_blank">sweet-sweep-3</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ngxrpi3e' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ngxrpi3e</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▄▆▇▇▇███</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.44357</td></tr><tr><td>val_char_acc</td><td>0.70735</td></tr><tr><td>val_word_acc</td><td>0.37196</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweet-sweep-3</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ngxrpi3e' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/ngxrpi3e</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_112117-ngxrpi3e/logs</code>
# wandb: Agent Starting Run: jg4qmfup with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 1
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hid_dim: 16
# wandb: 	lr: 0.0005
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_112705-jg4qmfup</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jg4qmfup' target="_blank">icy-sweep-4</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jg4qmfup' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jg4qmfup</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▆▆▅▄▄▃▂▁▁</td></tr><tr><td>val_char_acc</td><td>▁▁▁▂▂▄▅▆▇█</td></tr><tr><td>val_word_acc</td><td>▁▁▁▁▁▂▃▄▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>1.26324</td></tr><tr><td>val_char_acc</td><td>0.51211</td></tr><tr><td>val_word_acc</td><td>0.10601</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">icy-sweep-4</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jg4qmfup' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jg4qmfup</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_112705-jg4qmfup/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: oy66ss0h with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: RNN
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_113308-oy66ss0h</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/oy66ss0h' target="_blank">effortless-sweep-5</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/oy66ss0h' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/oy66ss0h</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▄▅▆▄▆▇▆█</td></tr><tr><td>val_word_acc</td><td>▁▅▅▆▇▆▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.34132</td></tr><tr><td>val_char_acc</td><td>0.70732</td></tr><tr><td>val_word_acc</td><td>0.37058</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">effortless-sweep-5</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/oy66ss0h' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/oy66ss0h</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_113308-oy66ss0h/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: qmdzeebt with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 5
# wandb: 	bidir: True
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_114340-qmdzeebt</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/qmdzeebt' target="_blank">winter-sweep-6</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/qmdzeebt' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/qmdzeebt</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▂▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▅▅▆█▇█▇█▇</td></tr><tr><td>val_word_acc</td><td>▁▅▅▇█▇█▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.15081</td></tr><tr><td>val_char_acc</td><td>0.74264</td></tr><tr><td>val_word_acc</td><td>0.42588</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">winter-sweep-6</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/qmdzeebt' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/qmdzeebt</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_114340-qmdzeebt/logs</code>
# wandb: Agent Starting Run: wkgidt54 with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 128
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.0005
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_114954-wkgidt54</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/wkgidt54' target="_blank">hopeful-sweep-7</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/wkgidt54' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/wkgidt54</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▅▆▇▇▇▇▇▇█</td></tr><tr><td>val_word_acc</td><td>▁▅▆▇▇▇█▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.27518</td></tr><tr><td>val_char_acc</td><td>0.73638</td></tr><tr><td>val_word_acc</td><td>0.41625</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hopeful-sweep-7</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/wkgidt54' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/wkgidt54</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_114954-wkgidt54/logs</code>
# wandb: Agent Starting Run: 6oy7vkp1 with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_115556-6oy7vkp1</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/6oy7vkp1' target="_blank">drawn-sweep-8</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/6oy7vkp1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/6oy7vkp1</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▃▅▆▇▇▇▇██</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆▇▇▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.22551</td></tr><tr><td>val_char_acc</td><td>0.73747</td></tr><tr><td>val_word_acc</td><td>0.41992</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">drawn-sweep-8</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/6oy7vkp1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/6oy7vkp1</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_115556-6oy7vkp1/logs</code>
# wandb: Agent Starting Run: 7j5g6s2f with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 32
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.0005
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_120159-7j5g6s2f</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7j5g6s2f' target="_blank">frosty-sweep-9</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7j5g6s2f' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7j5g6s2f</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▃▅▆▇▇▇▇██</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆▆▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.30898</td></tr><tr><td>val_char_acc</td><td>0.73908</td></tr><tr><td>val_word_acc</td><td>0.4229</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">frosty-sweep-9</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7j5g6s2f' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7j5g6s2f</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_120159-7j5g6s2f/logs</code>
# wandb: Agent Starting Run: 0zmzrg1r with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: True
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 32
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.0005
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_121334-0zmzrg1r</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0zmzrg1r' target="_blank">wobbly-sweep-10</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0zmzrg1r' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0zmzrg1r</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▃▅▅▆▇▇███</td></tr><tr><td>val_word_acc</td><td>▁▃▅▆▆▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.25565</td></tr><tr><td>val_char_acc</td><td>0.75449</td></tr><tr><td>val_word_acc</td><td>0.44539</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wobbly-sweep-10</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0zmzrg1r' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0zmzrg1r</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_121334-0zmzrg1r/logs</code>
# wandb: Agent Starting Run: cvujn8fn with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: RNN
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 16
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.0005
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_122508-cvujn8fn</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/cvujn8fn' target="_blank">frosty-sweep-11</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/cvujn8fn' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/cvujn8fn</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▅▆▇▇▇███</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.52796</td></tr><tr><td>val_char_acc</td><td>0.70158</td></tr><tr><td>val_word_acc</td><td>0.352</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">frosty-sweep-11</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/cvujn8fn' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/cvujn8fn</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_122508-cvujn8fn/logs</code>
# wandb: Agent Starting Run: h71p3f4f with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: True
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 32
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_123034-h71p3f4f</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/h71p3f4f' target="_blank">morning-sweep-12</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/h71p3f4f' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/h71p3f4f</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▄▆▆▇▇▇▇█</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆▆█▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.20207</td></tr><tr><td>val_char_acc</td><td>0.76184</td></tr><tr><td>val_word_acc</td><td>0.4548</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">morning-sweep-12</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/h71p3f4f' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/h71p3f4f</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_123034-h71p3f4f/logs</code>
# wandb: Agent Starting Run: 31285cs4 with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 16
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_124235-31285cs4</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/31285cs4' target="_blank">stoic-sweep-13</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/31285cs4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/31285cs4</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▅▆▆▇▇▇███</td></tr><tr><td>val_word_acc</td><td>▁▅▆▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.31636</td></tr><tr><td>val_char_acc</td><td>0.72671</td></tr><tr><td>val_word_acc</td><td>0.39422</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stoic-sweep-13</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/31285cs4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/31285cs4</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_124235-31285cs4/logs</code>
# wandb: Agent Starting Run: urcrdfq4 with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 5
# wandb: 	bidir: True
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_125425-urcrdfq4</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/urcrdfq4' target="_blank">earnest-sweep-14</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/urcrdfq4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/urcrdfq4</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▃▅▇██▇███</td></tr><tr><td>val_word_acc</td><td>▁▄▆▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.19697</td></tr><tr><td>val_char_acc</td><td>0.74944</td></tr><tr><td>val_word_acc</td><td>0.44355</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">earnest-sweep-14</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/urcrdfq4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/urcrdfq4</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_125425-urcrdfq4/logs</code>
# wandb: Agent Starting Run: jv69bgxm with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_130049-jv69bgxm</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jv69bgxm' target="_blank">driven-sweep-15</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jv69bgxm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jv69bgxm</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▅▆▇███▇▇</td></tr><tr><td>val_word_acc</td><td>▁▄▆▇▇▇██▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.2244</td></tr><tr><td>val_char_acc</td><td>0.72374</td></tr><tr><td>val_word_acc</td><td>0.39514</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">driven-sweep-15</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jv69bgxm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/jv69bgxm</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_130049-jv69bgxm/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: drfn92f6 with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.0005
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_131244-drfn92f6</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/drfn92f6' target="_blank">noble-sweep-16</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
# ...
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/4w31nhin' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/4w31nhin</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▆▇▇▇████</td></tr><tr><td>val_word_acc</td><td>▁▃▆▇▇▇██▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.16909</td></tr><tr><td>val_char_acc</td><td>0.74951</td></tr><tr><td>val_word_acc</td><td>0.43208</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">tough-sweep-37</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/4w31nhin' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/4w31nhin</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_165029-4w31nhin/logs</code>
# wandb: Agent Starting Run: 54iq48bh with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 128
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_165713-54iq48bh</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/54iq48bh' target="_blank">fallen-sweep-38</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/54iq48bh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/54iq48bh</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▃▅▅▅▇▇▇██</td></tr><tr><td>val_word_acc</td><td>▁▄▅▄▆▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.1949</td></tr><tr><td>val_char_acc</td><td>0.74413</td></tr><tr><td>val_word_acc</td><td>0.42336</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fallen-sweep-38</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/54iq48bh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/54iq48bh</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_165713-54iq48bh/logs</code>
# wandb: Agent Starting Run: 5hb4u3ys with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: True
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_170923-5hb4u3ys</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/5hb4u3ys' target="_blank">northern-sweep-39</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/5hb4u3ys' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/5hb4u3ys</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▆▇██████</td></tr><tr><td>val_word_acc</td><td>▁▄▅▇██████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.18172</td></tr><tr><td>val_char_acc</td><td>0.75033</td></tr><tr><td>val_word_acc</td><td>0.44034</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">northern-sweep-39</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/5hb4u3ys' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/5hb4u3ys</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_170923-5hb4u3ys/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: bt63xmer with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_172154-bt63xmer</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/bt63xmer' target="_blank">icy-sweep-40</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/bt63xmer' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/bt63xmer</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▅▆▆▆▇██▇█</td></tr><tr><td>val_word_acc</td><td>▁▅▆▆▆█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.22795</td></tr><tr><td>val_char_acc</td><td>0.73526</td></tr><tr><td>val_word_acc</td><td>0.4112</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">icy-sweep-40</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/bt63xmer' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/bt63xmer</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_172154-bt63xmer/logs</code>
# wandb: Agent Starting Run: aqraol75 with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 1
# wandb: 	bidir: True
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_173349-aqraol75</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/aqraol75' target="_blank">toasty-sweep-41</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/aqraol75' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/aqraol75</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▃▆▇█▇▇██▆</td></tr><tr><td>val_word_acc</td><td>▁▄▆▇▇▇▇█▇▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.16592</td></tr><tr><td>val_char_acc</td><td>0.73588</td></tr><tr><td>val_word_acc</td><td>0.41579</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">toasty-sweep-41</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/aqraol75' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/aqraol75</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250518_173349-aqraol75/logs</code>
# wandb: Agent Starting Run: plliepi7 with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 5
# wandb: 	bidir: True
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250518_174604-plliepi7</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/plliepi7' target="_blank">toasty-sweep-42</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/plliepi7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/plliepi7</a>

# %%
# ==============================================================
# 6) Sweep Configuration & Launch
# ==============================================================

sweep_cfg = {
    "method": "bayes",
    "metric": {"name": "val_char_acc", "goal": "maximize"},
    "parameters": {
        "batch_size": {"values": [32,64]},
        "emb_dim":    {"values": [16,32, 64, 128, 256]},
        "hid_dim":    {"values": [16,32, 64, 128, 256]},
        "cell_type":  {"values": ["RNN", "GRU", "LSTM"]},
        "beam_size":  {"values": [1, 3, 5]},
        "dropout":    {"values": [0.2, 0.3]},
        "bidir":      {"values": [True, False]},
        "lr":         {"values": [1e-3, 5e-4]},
        "tf_ratio":   {"values": [1]},
        "epochs":     {"value": 10}
    }
}

#sweep_id = wandb.sweep(sweep_cfg, project="dakshina-translit-hi")
sweep_id = 'i6h8vkm4'
wandb.agent(sweep_id, function=train_wandb, count=100,
            project="dakshina-translit-hi",entity='snehalma23m020-iit-madras')
#View sweep at https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4
# Out:
# wandb: Agent Starting Run: r6h32lze with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_035257-r6h32lze</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r6h32lze' target="_blank">golden-sweep-48</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r6h32lze' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r6h32lze</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▅▅▅▅▇▇▆▇█</td></tr><tr><td>val_word_acc</td><td>▁▅▅▆▆▇█▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.22082</td></tr><tr><td>val_char_acc</td><td>0.74017</td></tr><tr><td>val_word_acc</td><td>0.41349</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">golden-sweep-48</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r6h32lze' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r6h32lze</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_035257-r6h32lze/logs</code>
# wandb: Agent Starting Run: xxijv08e with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 3
# wandb: 	bidir: True
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 128
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_040415-xxijv08e</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xxijv08e' target="_blank">peachy-sweep-49</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xxijv08e' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xxijv08e</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▃▅▆▇█▇██▇</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆▆████▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.16531</td></tr><tr><td>val_char_acc</td><td>0.74875</td></tr><tr><td>val_word_acc</td><td>0.43162</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">peachy-sweep-49</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xxijv08e' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xxijv08e</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_040415-xxijv08e/logs</code>
# wandb: Agent Starting Run: r9t31ejt with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 5
# wandb: 	bidir: True
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 128
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_041558-r9t31ejt</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r9t31ejt' target="_blank">crimson-sweep-50</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r9t31ejt' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r9t31ejt</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▅▆██▇███</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆█▇▇██▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.18163</td></tr><tr><td>val_char_acc</td><td>0.74842</td></tr><tr><td>val_word_acc</td><td>0.43254</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">crimson-sweep-50</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r9t31ejt' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/r9t31ejt</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_041558-r9t31ejt/logs</code>
# wandb: Agent Starting Run: emmjgc4v with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 3
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 128
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_042153-emmjgc4v</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/emmjgc4v' target="_blank">glamorous-sweep-51</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/emmjgc4v' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/emmjgc4v</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▅▆▇▇▇███</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆▇████▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.21566</td></tr><tr><td>val_char_acc</td><td>0.73519</td></tr><tr><td>val_word_acc</td><td>0.40959</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glamorous-sweep-51</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/emmjgc4v' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/emmjgc4v</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_042153-emmjgc4v/logs</code>
# wandb: Agent Starting Run: 225mxfvf with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_043342-225mxfvf</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/225mxfvf' target="_blank">good-sweep-52</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/225mxfvf' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/225mxfvf</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▃▅▆▆▆▆█▇▇</td></tr><tr><td>val_word_acc</td><td>▁▄▅▆▆▆▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.2255</td></tr><tr><td>val_char_acc</td><td>0.73314</td></tr><tr><td>val_word_acc</td><td>0.40776</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">good-sweep-52</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/225mxfvf' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/225mxfvf</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_043342-225mxfvf/logs</code>
# wandb: Agent Starting Run: egmon2br with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 3
# wandb: 	bidir: True
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_044535-egmon2br</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/egmon2br' target="_blank">desert-sweep-53</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/egmon2br' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/egmon2br</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▆▇▆██▇██</td></tr><tr><td>val_word_acc</td><td>▁▄▆▇▆█▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.17014</td></tr><tr><td>val_char_acc</td><td>0.74716</td></tr><tr><td>val_word_acc</td><td>0.43575</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">desert-sweep-53</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/egmon2br' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/egmon2br</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_044535-egmon2br/logs</code>
# wandb: Agent Starting Run: 58gesi0t with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 128
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_045159-58gesi0t</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/58gesi0t' target="_blank">stellar-sweep-54</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/58gesi0t' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/58gesi0t</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▅▆▆▇▇▇▇██</td></tr><tr><td>val_word_acc</td><td>▁▅▆▆▇▇█▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.21741</td></tr><tr><td>val_char_acc</td><td>0.7378</td></tr><tr><td>val_word_acc</td><td>0.42267</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-sweep-54</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/58gesi0t' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/58gesi0t</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_045159-58gesi0t/logs</code>
# wandb: Agent Starting Run: 0za4rmi4 with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 1
# wandb: 	bidir: False
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_050349-0za4rmi4</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0za4rmi4' target="_blank">light-sweep-55</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0za4rmi4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0za4rmi4</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▆▇▆▅▇▆█▇</td></tr><tr><td>val_word_acc</td><td>▁▄▆█▆▆▇▆█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.25303</td></tr><tr><td>val_char_acc</td><td>0.72249</td></tr><tr><td>val_word_acc</td><td>0.39009</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">light-sweep-55</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0za4rmi4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/0za4rmi4</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_050349-0za4rmi4/logs</code>
# wandb: Agent Starting Run: xwqwthel with config:
# wandb: 	batch_size: 64
# wandb: 	beam_size: 5
# wandb: 	bidir: False
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 128
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_051458-xwqwthel</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xwqwthel' target="_blank">dainty-sweep-56</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xwqwthel' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xwqwthel</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▁▁▁▁</td></tr><tr><td>val_char_acc</td><td>▁▄▅▆▆▇██▇█</td></tr><tr><td>val_word_acc</td><td>▁▄▆▆▆▇██▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.23198</td></tr><tr><td>val_char_acc</td><td>0.74126</td></tr><tr><td>val_word_acc</td><td>0.42152</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dainty-sweep-56</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xwqwthel' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/xwqwthel</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_051458-xwqwthel/logs</code>
# wandb: Agent Starting Run: 7p78vvxg with config:
# wandb: 	batch_size: 32
# wandb: 	beam_size: 3
# wandb: 	bidir: True
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hid_dim: 256
# wandb: 	lr: 0.001
# wandb: 	tf_ratio: 1
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_052057-7p78vvxg</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7p78vvxg' target="_blank">autumn-sweep-57</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/sweeps/i6h8vkm4</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7p78vvxg' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/dakshina-translit-hi/runs/7p78vvxg</a>

# %% [markdown]
# # Step 11 : The best hyperparameters obtained are

# %% [markdown]
# # batch_size = 32,
# # beam_size  = 5,
# # bidir      = True,
# # cell_type  = "LSTM",
# # dropout    = 0.3,
# # emb_dim    = 32,
# # epochs     = 10,
# # hid_dim    = 256,
# # lr         = 0.001,
# # tf_ratio   = 1.0,

# %% [markdown]
# # Step 12 : Train single-layer bidirectional Seq2Seq model with Bahdanau attention

# %%
# best hyper-parameters found by sweep
BEST_CFG = dict(
    batch_size = 32,
    beam_size  = 5,
    bidir      = True,
    cell_type  = "LSTM",
    dropout    = 0.3,
    emb_dim    = 32,
    epochs     = 10,
    hid_dim    = 256,
    lr         = 1e-3,
    tf_ratio   = 1.0,     # teacher forcing
)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
random.seed(42); np.random.seed(42); torch.manual_seed(42); torch.cuda.manual_seed_all(42)

# %%
def load_pairs(path):
    df = (pd.read_csv(path, sep="\t", names=["native","latin","count"], dtype=str)
            .dropna(subset=["native","latin"]))
    df["native"] = df["native"].str.strip(); df["latin"] = df["latin"].str.strip()
    df = df[(df["native"]!="") & (df["latin"]!="")]
    return list(zip(df["latin"], df["native"]))

class DakshinaDS(Dataset):
    def __init__(self, pairs, s2i, t2i, max_src, max_tgt):
        self.pairs, self.s2i, self.t2i = pairs, s2i, t2i
        self.max_src, self.max_tgt = max_src, max_tgt
        self.pad_s, self.pad_t = s2i["<pad>"], t2i["<pad>"]
    def __len__(self): return len(self.pairs)
    def __getitem__(self, idx):
        latin, deva = self.pairs[idx]
        src = [self.s2i["<sos>"]] + [self.s2i.get(c,self.s2i["<unk>"]) for c in latin] + [self.s2i["<eos>"]]
        tgt = [self.t2i["<sos>"]] + [self.t2i.get(c,self.t2i["<unk>"]) for c in deva]  + [self.t2i["<eos>"]]
        src = src[:self.max_src] + [self.pad_s]*(self.max_src-len(src))
        tgt = tgt[:self.max_tgt]+ [self.pad_t]*(self.max_tgt-len(tgt))
        return torch.tensor(src), torch.tensor(tgt)

# %%
# Seq2Seq-with-Attention  
class Seq2SeqAttn(nn.Module):
    def __init__(self, src_vocab, tgt_vocab, cfg):
        super().__init__()
        rnn_cls = getattr(nn,cfg["cell_type"])
        self.src_emb = nn.Embedding(src_vocab, cfg["emb_dim"], padding_idx=0)
        self.tgt_emb = nn.Embedding(tgt_vocab, cfg["emb_dim"], padding_idx=0)
        self.encoder = rnn_cls(cfg["emb_dim"], cfg["hid_dim"], 1, batch_first=True,
                               bidirectional=cfg["bidir"])
        enc_out_dim  = cfg["hid_dim"]*(2 if cfg["bidir"] else 1)
        if cfg["bidir"]: self.bridge = nn.Linear(enc_out_dim, cfg["hid_dim"])
        self.attn = BahdanauAttn(enc_out_dim, cfg["hid_dim"])
        self.decoder = rnn_cls(cfg["emb_dim"]+enc_out_dim, cfg["hid_dim"], 1, batch_first=True)
        self.fc_out = nn.Linear(cfg["hid_dim"], tgt_vocab)
        self.cfg, self.bidir = cfg, cfg["bidir"]

    def _init_dec_state(self, enc_h):
        if self.bidir:
            if self.cfg["cell_type"]=="LSTM":
                h,c=enc_h
                h=torch.cat([h[-2],h[-1]],1); c=torch.cat([c[-2],c[-1]],1)
                h,c=self.bridge(h).unsqueeze(0),self.bridge(c).unsqueeze(0)
                return (h,c)
            else:
                h=torch.cat([enc_h[-2],enc_h[-1]],1)
                return self.bridge(h).unsqueeze(0)
        else:
            return enc_h

    def forward(self, src, tgt, tf_ratio=1.0):
        B,S=src.size(); T=tgt.size(1)
        mask=(src!=0)
        enc_outs, enc_h = self.encoder(self.src_emb(src))
        dec_h = self._init_dec_state(enc_h)
        logits = torch.zeros(B,T,self.fc_out.out_features,device=src.device)
        inp = tgt[:,0]
        for t in range(1,T):
            emb = self.tgt_emb(inp).unsqueeze(1)
            dec_last = dec_h[0][-1] if self.cfg["cell_type"]=="LSTM" else dec_h[-1]
            ctx,_ = self.attn(dec_last,enc_outs,mask)
            dec_in = torch.cat([emb,ctx.unsqueeze(1)],2)
            dec_out,dec_h = self.decoder(dec_in,dec_h)
            pred = self.fc_out(dec_out.squeeze(1))
            logits[:,t]=pred
            use_teacher = random.random()<tf_ratio
            inp = tgt[:,t] if use_teacher else pred.argmax(1)
        return logits

    # ---------- Greedy OR Beam search decoding --------------
    def decode(self, src, sos, eos, beam=1, max_len=50):
        """
        src: [S] tensor. Returns list[str] (top-1 prediction).
        """
        with torch.no_grad():
            src = src.unsqueeze(0).to(DEVICE)
            mask=(src!=0)
            enc_outs, enc_h = self.encoder(self.src_emb(src))
            if beam==1:                              # ----- GREEDY -----
                dec_h = self._init_dec_state(enc_h)
                inp   = torch.tensor([sos],device=DEVICE)
                out_chars=[]
                for _ in range(max_len):
                    emb=self.tgt_emb(inp).unsqueeze(0)
                    dec_last = dec_h[0][-1] if self.cfg["cell_type"]=="LSTM" else dec_h[-1]
                   
                    ctx,_=self.attn(dec_last,enc_outs,mask)
                    dec_in=torch.cat([emb,ctx.unsqueeze(1)],2)
                    
                    dec_out,dec_h=self.decoder(dec_in,dec_h)
                    pred=self.fc_out(dec_out.squeeze(1)).argmax(1)
                    if pred.item()==eos:break
                    out_chars.append(pred.item()); inp=pred
                return out_chars
            # ----------------- BEAM >1 -------------------------
            else:
                dec_h0=self._init_dec_state(enc_h)
                beams=[([],0.0,dec_h0,torch.tensor([sos],device=DEVICE))]
                finished=[]
                for _ in range(max_len):
                    new_beams=[]
                    for seq,score,h,inp in beams:
                        emb=self.tgt_emb(inp).unsqueeze(0)
                        dec_last = h[0][-1] if self.cfg["cell_type"]=="LSTM" else h[-1]
                        
                        ctx,_=self.attn(dec_last,enc_outs,mask)
                        dec_in=torch.cat([emb,ctx.unsqueeze(1)],2)
                        
                        dec_out,h_next=self.decoder(dec_in,h)
                        log_probs=torch.log_softmax(self.fc_out(dec_out.squeeze(1)),dim=1)
                        topk=log_probs.topk(beam)
                        for log_p,idx in zip(topk.values[0],topk.indices[0]):
                            idx=int(idx); log_p=float(log_p)
                            if idx==eos:
                                finished.append((seq,score+log_p))
                            else:
                                new_beams.append((seq+[idx],score+log_p,h_next,torch.tensor([idx],device=DEVICE)))
                    beams=sorted(new_beams,key=lambda x:x[1],reverse=True)[:beam]
                    if not beams: break
                if not finished: finished=[max(beams,key=lambda x:x[1])[:2]]
                best_seq=sorted(finished,key=lambda x:x[1],reverse=True)[0][0]
                return best_seq





# to calculate accuracy
def accuracy_greedy(model, loader, idx2c, eos, pad):
    model.eval(); corr=tot_w=0
    with torch.no_grad():
        for src,tgt in loader:
            src,tgt = src.to(DEVICE), tgt.to(DEVICE)
            pred = model(src,tgt,tf_ratio=0).argmax(-1)[:,1:]
            gold = tgt[:,1:]
            for p,g in zip(pred,gold):
                p,g = p.tolist(), g.tolist()
                if eos in p: p = p[:p.index(eos)]
                if eos in g: g = g[:g.index(eos)]
                corr += int("".join(idx2c[i] for i in p) == "".join(idx2c[i] for i in g))
                tot_w+=1
    return corr/tot_w


# Beam-aware exact-match accuracy  

def accuracy_beam(model, pairs, s2i, t2i, idx2c, cfg):
    PAD,SOS,EOS = t2i["<pad>"], t2i["<sos>"], t2i["<eos>"]
    max_src = max(len(p[0]) for p in pairs)+2
    max_len = max(len(p[1]) for p in pairs)+2
    corr=0
    model.eval()
    with torch.no_grad():
        for latin,gold in pairs:
            src_idx=[SOS]+[s2i.get(c,s2i["<unk>"]) for c in latin]+[EOS]
            src_idx=src_idx[:max_src]+[PAD]*(max_src-len(src_idx))
            pred_idx=model.decode(torch.tensor(src_idx),SOS,EOS,
                                  beam=cfg["beam_size"],max_len=max_len)
            pred_str="".join(idx2c[i] for i in pred_idx)
            corr+= int(pred_str==gold)
    return corr/len(pairs)

# %%
# Load data

ROOT="/kaggle/input/snehal"      # adjust if paths differ
train_pairs = load_pairs(os.path.join(ROOT,"hi.translit.sampled.train.tsv"))
dev_pairs   = load_pairs(os.path.join(ROOT,"hi.translit.sampled.dev.tsv"))
test_pairs  = load_pairs(os.path.join(ROOT,"hi.translit.sampled.test.tsv"))

src_vocab, tgt_vocab = build_vocab(train_pairs)
s2i = {c:i for i,c in enumerate(src_vocab)}
t2i = {c:i for i,c in enumerate(tgt_vocab)}
i2t = {i:c for c,i in t2i.items()}
PAD, SOS, EOS = t2i["<pad>"], t2i["<sos>"], t2i["<eos>"]

# finding the max len
max_src = max(len(x[0]) for x in train_pairs)+2
max_tgt = max(len(x[1]) for x in train_pairs)+2

train_ds = DakshinaDS(train_pairs, s2i, t2i, max_src, max_tgt)
dev_ds   = DakshinaDS(dev_pairs,   s2i, t2i, max_src, max_tgt)
test_ds  = DakshinaDS(test_pairs,  s2i, t2i, max_src, max_tgt)

train_ld = DataLoader(train_ds,batch_size=BEST_CFG["batch_size"],shuffle=True)
dev_ld   = DataLoader(dev_ds,  batch_size=BEST_CFG["batch_size"])


# Train
model = Seq2SeqAttn(len(src_vocab), len(tgt_vocab), BEST_CFG).to(DEVICE)
opt   = optim.Adam(model.parameters(), lr=BEST_CFG["lr"])
criterion = nn.CrossEntropyLoss(ignore_index=PAD)

for epoch in range(1, BEST_CFG["epochs"]+1):
    model.train(); ep_loss=0
    for src,tgt in tqdm(train_ld,leave=False):
        src,tgt = src.to(DEVICE), tgt.to(DEVICE)
        logits  = model(src,tgt,tf_ratio=BEST_CFG["tf_ratio"])
        loss = criterion(logits[:,1:].reshape(-1,logits.size(-1)),
                         tgt[:,1:].reshape(-1))
        opt.zero_grad(); loss.backward(); opt.step(); ep_loss+=loss.item()
    dev_acc = accuracy_greedy(model, dev_ld, i2t, EOS, PAD)
    print(f"Epoch {epoch:02d} | loss {ep_loss/len(train_ld):.3f} | dev exact-match (greedy) {dev_acc:.4f}")


#  finding the accuracy on the test set and saving it tsv and csv format
test_exact = accuracy_beam(model, test_pairs, s2i, t2i, i2t, BEST_CFG)
print(f"\nTEST exact-match accuracy with beam={BEST_CFG['beam_size']}: {test_exact:.4f}")

pred_dir = pathlib.Path("predictions_attention"); pred_dir.mkdir(exist_ok=True)
out_path = pred_dir/"predictions_attn.tsv"
with out_path.open("w",encoding="utf8") as f:
    f.write("latin\tpredicted\tgold\n")
    for latin,gold in tqdm(test_pairs):
        src_idx=[SOS]+[s2i.get(c,s2i["<unk>"]) for c in latin]+[EOS]
        src_idx=src_idx[:max_src]+[PAD]*(max_src-len(src_idx))
        pred_idx=model.decode(torch.tensor(src_idx),SOS,EOS,
                              beam=BEST_CFG["beam_size"],max_len=max_tgt)
        pred_str="".join(i2t[i] for i in pred_idx)
        f.write(f"{latin}\t{pred_str}\t{gold}\n")

print(f"\n→ Predictions saved to {out_path.resolve()}")
# Out:
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 01 | loss 0.903 | dev exact-match (greedy) 0.3210
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 02 | loss 0.405 | dev exact-match (greedy) 0.3839
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 03 | loss 0.324 | dev exact-match (greedy) 0.3931
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 04 | loss 0.276 | dev exact-match (greedy) 0.4174
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 05 | loss 0.231 | dev exact-match (greedy) 0.4351
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 06 | loss 0.192 | dev exact-match (greedy) 0.4309
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 07 | loss 0.172 | dev exact-match (greedy) 0.4419
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 08 | loss 0.141 | dev exact-match (greedy) 0.4362
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 09 | loss 0.122 | dev exact-match (greedy) 0.4208
#   0%|          | 0/1382 [00:00<?, ?it/s]
# Epoch 10 | loss 0.106 | dev exact-match (greedy) 0.4146
#
# TEST exact-match accuracy with beam=5: 0.4240
#   0%|          | 0/4502 [00:00<?, ?it/s]
# → Predictions saved to /kaggle/working/predictions_attention/predictions_attn.tsv

# %%
df_preds = pd.read_csv(out_path, sep="\t", encoding="utf-8")   # read the TSV we just wrote
csv_path = pred_dir / "predictions_attn.csv"
df_preds.to_csv(csv_path, index=False, encoding="utf-8")
print(f"→ Predictions also saved to {csv_path.resolve()}")
# Out:
# → Predictions also saved to /kaggle/working/predictions_attention/predictions_attn.csv

# %% [markdown]
# # Step 13 : Hindi Transliteration prediction grid

# %%
# Adjusted filenames
pred_dir = Path("predictions_attention")     
tsv_file = pred_dir / "predictions_attn.tsv" 
csv_file = pred_dir / "predictions_attn.csv"

pred_dir.mkdir(exist_ok=True)

# Load or regenerate if missing
if tsv_file.exists():
    df = pd.read_csv(tsv_file, sep="\t", encoding="utf-8")
elif csv_file.exists():
    df = pd.read_csv(csv_file, encoding="utf-8")
else:
    print("predictions_attn file not found — regenerating from model …")
    PAD, SOS, EOS = t2i["<pad>"], t2i["<sos>"], t2i["<eos>"]
    max_src = max(len(x[0]) for x in test_pairs) + 2
    max_tgt = max(len(x[1]) for x in test_pairs) + 2

    rows = []
    model.eval()
    with torch.no_grad():
        for latin, gold in test_pairs:
            src_idx = [SOS] + [s2i.get(c, s2i["<unk>"]) for c in latin] + [EOS]
            src_idx = src_idx[:max_src] + [PAD]*(max_src-len(src_idx))
            pred = model.decode(torch.tensor(src_idx), SOS, EOS,
                                beam=BEST_CFG["beam_size"], max_len=max_tgt)
            rows.append((latin, gold, "".join(i2t[i] for i in pred)))

    df = pd.DataFrame(rows, columns=["latin", "gold", "predicted"])
    df.to_csv(tsv_file, sep="\t", index=False, encoding="utf-8")
    print(f"✓ regenerated {tsv_file}")

# Build tuple list
predictions = list(zip(df["latin"], df["gold"], df["predicted"]))

#  HTML table format
def display_colored_prediction_grid(predictions, n=20):
    view = pd.DataFrame(predictions[:n],
                        columns=["Latin", "Reference", "Predicted"])
    html = '<h3>Hindi Transliteration: Prediction Grid</h3>'
    html += """
    <style>
      table.pred-table{border-collapse:collapse;font-family:monospace;}
      table.pred-table th,td{border:1px solid #ccc;padding:6px 14px;text-align:center;}
    </style><table class="pred-table"><thead>
      <tr><th>#</th><th>Latin</th><th>Predicted</th><th>Reference</th><th>Status</th></tr>
    </thead><tbody>"""
    for i,row in view.iterrows():
        ok   = row["Predicted"] == row["Reference"]
        bg   = "#d4edda" if ok else "#f8d7da"
        brd  = "#28a745" if ok else "#dc3545"
        stat = "CORRECT" if ok else "INCORRECT"
        html += f'<tr style="background:{bg};border:2px solid {brd};"><td>{i+1}</td>' \
                f'<td><b>{row["Latin"]}</b></td>' \
                f'<td style="border:2px solid {brd};">{row["Predicted"]}</td>' \
                f'<td style="border:2px solid {brd};">{row["Reference"]}</td>' \
                f'<td>{stat}</td></tr>'
    html += '</tbody></table>'
    display(HTML(html))

# Show first 50 rows 
display_colored_prediction_grid(predictions, n=50)
# Out:
# <h3>Hindi Transliteration: Prediction Grid</h3>
#     <style>
#       table.pred-table{border-collapse:collapse;font-family:monospace;}
#       table.pred-table th,td{border:1px solid #ccc;padding:6px 14px;text-align:center;}
#     </style><table class="pred-table"><thead>
#       <tr><th>#</th><th>Latin</th><th>Predicted</th><th>Reference</th><th>Status</th></tr>
#     </thead><tbody><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>1</td><td><b>ank</b></td><td style="border:2px solid #dc3545;">एंक</td><td style="border:2px solid #dc3545;">अंक</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>2</td><td><b>anka</b></td><td style="border:2px solid #dc3545;">अंका</td><td style="border:2px solid #dc3545;">अंक</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>3</td><td><b>ankit</b></td><td style="border:2px solid #dc3545;">एंक्टिट</td><td style="border:2px solid #dc3545;">अंकित</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>4</td><td><b>anakon</b></td><td style="border:2px solid #dc3545;">अनकों</td><td style="border:2px solid #dc3545;">अंकों</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>5</td><td><b>ankhon</b></td><td style="border:2px solid #dc3545;">आंखों</td><td style="border:2px solid #dc3545;">अंकों</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>6</td><td><b>ankon</b></td><td style="border:2px solid #dc3545;">ंकोण</td><td style="border:2px solid #dc3545;">अंकों</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>7</td><td><b>angkor</b></td><td style="border:2px solid #dc3545;">अंगोर</td><td style="border:2px solid #dc3545;">अंकोर</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>8</td><td><b>ankor</b></td><td style="border:2px solid #dc3545;">एनकोर</td><td style="border:2px solid #dc3545;">अंकोर</td><td>INCORRECT</td></tr><tr style="background:#d4edda;border:2px solid #28a745;"><td>9</td><td><b>angaarak</b></td><td style="border:2px solid #28a745;">अंगारक</td><td style="border:2px solid #28a745;">अंगारक</td><td>CORRECT</td></tr><tr style="background:#d4edda;border:2px solid #28a745;"><td>10</td><td><b>angarak</b></td><td style="border:2px solid #28a745;">अंगारक</td><td style="border:2px solid #28a745;">अंगारक</td><td>CORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>11</td><td><b>angraji</b></td><td style="border:2px solid #dc3545;">अंग्रजी</td><td style="border:2px solid #dc3545;">अंग्रज़ी</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>12</td><td><b>angreji</b></td><td style="border:2px solid #dc3545;">अंग्रेजी</td><td style="border:2px solid #dc3545;">अंग्रज़ी</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>13</td><td><b>angrzi</b></td><td style="border:2px solid #dc3545;">अंग्रजी</td><td style="border:2px solid #dc3545;">अंग्रज़ी</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>14</td><td><b>antah</b></td><td style="border:2px solid #dc3545;">अंताह</td><td style="border:2px solid #dc3545;">अंतः</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>15</td><td><b>antaha</b></td><td style="border:2px solid #dc3545;">अंताहा</td><td style="border:2px solid #dc3545;">अंतः</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>16</td><td><b>antarmukh</b></td><td style="border:2px solid #dc3545;">अंतरमुख</td><td style="border:2px solid #dc3545;">अंतर्मुख</td><td>INCORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>17</td><td><b>antmurkh</b></td><td style="border:2px solid #dc3545;">अंतरूख</td><td style="border:2px solid #dc3545;">अंतर्मुख</td><td>INCORRECT</td></tr><tr style="background:#d4edda;border:2px solid #28a745;"><td>18</td><td><b>antrmukh</b></td><td style="border:2px solid #28a745;">अंतर्मुख</td><td style="border:2px solid #28a745;">अंतर्मुख</td><td>CORRECT</td></tr><tr style="background:#f8d7da;border:2px solid #dc3545;"><td>19</td><td><b>andrabee</b></td><td style="border:2px solid #dc3545;">अंद्रबी</td><td style="border:2px solid #dc3545;">अंद्राबी</td><td>INCORR ...

# %% [markdown]
# # Step 14 : Attention heat maps

# %%
# --- device fallback in case you restarted the kernel ----------
try:
    DEVICE
except NameError:
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

SOS, EOS, PAD = t2i["<sos>"], t2i["<eos>"], t2i["<pad>"]


#  decode ONE word & capture its attention matrix

def _decode_with_attention(word: str, max_len=50):
    src_ids = [SOS] + [s2i.get(c, s2i["<unk>"]) for c in word] + [EOS]
    src     = torch.tensor(src_ids, device=DEVICE).unsqueeze(0)  
    mask    = src != PAD

    with torch.no_grad():
        enc_out, enc_h = model.encoder(model.src_emb(src))
        dec_h = model._init_dec_state(enc_h)

    src_chars  = list(word) + ["<eos>"]
    out_chars  = []
    rows = []
    inp = torch.tensor([SOS], device=DEVICE)

    for _ in range(max_len):
        emb = model.tgt_emb(inp).unsqueeze(1)                     
        last_h = dec_h[0][-1] if BEST_CFG["cell_type"] == "LSTM" else dec_h[-1]
        ctx, attn = model.attn(last_h, enc_out, mask)            
        rows.append(attn.squeeze(0).detach().cpu().numpy())              

        
        dec_in = torch.cat([emb, ctx.unsqueeze(1)], 2)
        with torch.no_grad():
            dec_out, dec_h = model.decoder(dec_in, dec_h)

        nxt = model.fc_out(dec_out.squeeze(1)).argmax(1)
        if nxt.item() == EOS:
            break
        out_chars.append(i2t[nxt.item()])
        inp = nxt

    A = np.stack(rows)                                         
    return "".join(out_chars), src_chars, A



#  draw a 3×3 grid of heat-maps

def plot_attention_grid(model,test_pairs,n_examples: int = 9,save_path: str | None = "predictions_attention/attention_grid.png", cmap: str = "viridis"):
    # n_examples  total examples to show (first N from test_pairs)
    
    rows = cols = 3
    per_fig = rows * cols
    n_figs  = ceil(n_examples / per_fig)
    sample  = test_pairs[:n_examples]

    if save_path is not None:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)

    for f in range(n_figs):
        fig, axes = plt.subplots(rows, cols, figsize=(cols*4, rows*4))
        axes = axes.flatten()

        for k, ax in enumerate(axes):
            idx = f * per_fig + k
            if idx >= n_examples:
                ax.axis("off")
                continue

            latin, gold = sample[idx]
            pred, src_chars, A_full = _decode_with_attention(latin)

            # crop: drop <sos> column and pad beyond src_chars
            S_true = len(src_chars) + 1           # incl <sos> we dropped
            A = A_full[:, 1:S_true]               # [T_out, len(src_chars)]

            # plot rows=input, cols=output  ->  transpose
            im = ax.imshow(A.T,
                           origin='lower',
                           aspect='auto',
                           vmin=0, vmax=1,
                           cmap=cmap)

            # ticks
            ax.set_yticks(range(len(src_chars)))
            ax.set_yticklabels(src_chars, fontsize=8)
            dst_chars = list(pred) + ["<eos>"]
            ax.set_xticks(range(len(dst_chars)))
            ax.set_xticklabels(dst_chars, rotation=90, fontsize=8)

            ax.set_ylabel("Input Sequence",  fontsize=9)
            ax.set_xlabel("Output Sequence", fontsize=9)

            status = "✔" if pred == gold else "✘"
            ax.set_title(f"Input: {repr(src_chars[:-1])}\nPredicted: {pred} {status}",
                         fontsize=10)

            fig.colorbar(im, ax=ax, fraction=0.046, pad=0.03)

        plt.tight_layout()
        if save_path:
            base, ext = os.path.splitext(save_path)
            fname = f"{base}_batch{f+1}{ext}"
            fig.savefig(fname, dpi=300, bbox_inches="tight")
            print(f"saved {fname}")
        plt.show()



font_path = Path("/kaggle/input/hindi-scipt/NotoSansDevanagari-VariableFont_wdth,wght.ttf")
fm.fontManager.addfont(str(font_path))         # add to Matplotlib’s cache
#plt.rcParams["font.family"] = "Noto Sans Devanagari"    
plt.rcParams["font.family"] = ["Noto Sans Devanagari", "DejaVu Sans"]

plot_attention_grid(model,test_pairs,n_examples=10,save_path="predictions_attention/attention_grid.png",cmap="turbo")
# Out:
# saved predictions_attention/attention_grid_batch1.png
# saved predictions_attention/attention_grid_batch2.png
